# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the CSV data file into our DataFrame:

# %%
df= pd.read_csv('/Users/mikeredshaw/Documents/Schulich MBAN/MMAI 5100 - Database Fundamentals/Group Project Data-SFD Data-Toronto Police (1).csv')

# %%
df
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5702 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5703 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5704 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5705 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5706 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
#       OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 0         2004        May   Saturday      136       15  ...           Night  \
# 1         2004       July     Monday      208       26  ...         Evening
# 2         2004        May     Friday      135       14  ...       Afternoon
# 3         2004   December     Sunday      354       19  ...           Night
# 4         2004      April     Monday      103       12  ...         Evening
# ...        ...        ...        ...      ...      ...  ...             ...
# 5702      2022       June   Thursday      153        2  ...           Night
# 5703      2022       July     Sunday      198       17  ...           Night
# 5704      2022   February     Monday       52       21  ...           Night
# 5705      2022  September     Sunday      254       11  ...           Night
# 5706      2022      April  Wednesday      117       27  ...       Afternoon
#
#      DIVISION DEATH  INJURIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0         D41     0         0       142            Woburn North      137  \
# 1         D23     0         0         1  West Humber-Clairville        1
# 2         D31     1         1        24             Black Creek       24
# 3         D51     1         0       168     Downtown Yonge East       75
# 4         D42     0         0       146            Malvern East      132
# ...       ...   ...       ...       ...                     ...      ...
# 5702      D33     0         1        53              Henry Farm       53
# 5703      D14     1         1       164        Wellington Place       77
# 5704      D43     0         0       135             Morningside      135
# 5705      D11     0         2        83          Dufferin Grove       83
# 5706      D51     0         0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                               Woburn (137) -79.234955  43.781528
# 1                 West Humber-Clairville (1) -79.618218  43.733547
# 2                           Black Creek (24) -79.518759  43.769157
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665
# 4                              Malvern (132) -79.212435  43.812075
# ...                                      ...        ...        ...
# 5702                         Henry Farm (53) -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920
# 5704                       Morningside (135) -79.196217  43.786621
# 5705                     Dufferin Grove (83) -79.443993  43.658083
# 5706                          Moss Park (73) -79.369456  43.654519
#
# [5707 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5707 non-null   float64
#  1   Y                  5707 non-null   float64
#  2   OBJECTID           5707 non-null   int64
#  3   EVENT_UNIQUE_ID    5707 non-null   object
#  4   OCC_DATE           5707 non-null   object
#  5   OCC_YEAR           5707 non-null   int64
#  6   OCC_MONTH          5707 non-null   object
#  7   OCC_DOW            5707 non-null   object
#  8   OCC_DOY            5707 non-null   int64
#  9   OCC_DAY            5707 non-null   int64
#  10  OCC_HOUR           5707 non-null   int64
#  11  OCC_TIME_RANGE     5707 non-null   object
#  12  DIVISION           5707 non-null   object
#  13  DEATH              5707 non-null   int64
#  14  INJURIES           5707 non-null   int64
#  15  HOOD_158           5707 non-null   object
#  16  NEIGHBOURHOOD_158  5707 non-null   object
#  17  HOOD_140           5707 non-null   object
#  18  NEIGHBOURHOOD_140  5707 non-null   object
#  19  LONG_WGS84         5707 non-null   float64
#  20  LAT_WGS84          5707 non-null   float64
# dtypes: float64(4), int64(7), object(10)
# memory usage: 936.4+ KB

# %%
df.describe(include='all')
# Out:
#                   X            Y     OBJECTID EVENT_UNIQUE_ID
# count   5707.000000  5707.000000  5707.000000            5707  \
# unique          NaN          NaN          NaN            5707
# top             NaN          NaN          NaN   GO-2004397105
# freq            NaN          NaN          NaN               1
# mean     -79.481115    43.244138  2854.000000             NaN
# std        0.640212     4.532671  1647.613324             NaN
# min      -85.488744     0.000000     1.000000             NaN
# 25%      -79.513346    43.676604  1427.500000             NaN
# 50%      -79.439740    43.720796  2854.000000             NaN
# 75%      -79.328082    43.755306  4280.500000             NaN
# max      -79.122053    43.838273  5707.000000             NaN
#
#                       OCC_DATE     OCC_YEAR OCC_MONTH OCC_DOW      OCC_DOY
# count                     5707  5707.000000      5707    5707  5707.000000  \
# unique                    3579          NaN        12       7          NaN
# top     2019/08/05 04:00:00+00          NaN    August  Sunday          NaN
# freq                         9          NaN       604     995          NaN
# mean                       NaN  2014.460662       NaN     NaN   187.198178
# std                        NaN     5.468803       NaN     NaN   100.269326
# min                        NaN  2004.000000       NaN     NaN     1.000000
# 25%                        NaN  2010.000000       NaN     NaN   106.000000
# 50%                        NaN  2016.000000       NaN     NaN   192.000000
# 75%                        NaN  2019.000000       NaN     NaN   268.000000
# max                        NaN  2022.000000       NaN     NaN   366.000000
#
#             OCC_DAY  ...  OCC_TIME_RANGE DIVISION        DEATH     INJURIES
# count   5707.000000  ...            5707     5707  5707.000000  5707.000000  \
# unique          NaN  ...               4       17          NaN          NaN
# top             NaN  ...         Evening      D31          NaN          NaN
# freq            NaN  ...            2307      998          NaN          NaN
# mean      15.901174  ...             NaN      NaN     0.122481     0.488172
# std        8.819631  ...             NaN      NaN     0.349599     0.779148
# min        1.000000  ...             NaN      NaN     0.000000     0.000000
# 25%        8.000000  ...             NaN      NaN     0.000000     0.000000
# 50%       16.000000  ...             NaN      NaN     0.000000     0.000000
# 75%       23.000000  ...             NaN      NaN     0.000000     1.000000
# max       31.000000  ...             NaN      NaN     3.000000    24.000000
#
#         HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# count       5707                    5707     5707  \
# unique       159                     159      140
# top           25  Glenfield-Jane Heights       25
# freq         311                     311      304
# mean         NaN                     NaN      NaN
# std          NaN                     NaN      NaN
# min          NaN                     NaN      NaN
# 25%          NaN                     NaN      NaN
# 50%          NaN                     NaN      NaN
# 75%          NaN                     NaN      NaN
# max          NaN                     NaN      NaN
#
#                   NEIGHBOURHOOD_140   LONG_WGS84    LAT_WGS84
# count                          5707  5707.000000  5707.000000
# unique                          140          NaN          NaN
# top     Glenfield-Jane Heights (25)          NaN          NaN
# freq                            304          NaN          NaN
# mean                            NaN   -79.481115    43.244138
# std                             NaN     0.640212     4.532671
# min                             NaN   -85.488744     0.000000
# 25%                             NaN   -79.513346    43.676604
# 50%                             NaN   -79.439740    43.720796
# 75%                             NaN   -79.328082    43.755306
# max                             NaN   -79.122053    43.838273
#
# [11 rows x 21 columns]

# %% [markdown]
# Check for any null values in the dataset:

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Noticed some 0 values in Y and LAT_WGS84, seems as though these incidents don't have reliable location data, so we're going to drop them as accurate location data is important for our purposes and the total number of entries with this is relatively small compared to the entire data set.

# %%
df[df['Y']== 0]
# Out:
#               X    Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 9    -85.488744  0.0        10   GO-2004683174  2004/10/15 04:00:00+00  \
# 22   -85.488744  0.0        23   GO-2004591518  2004/09/03 04:00:00+00
# 27   -85.488744  0.0        28   GO-2004577384  2004/07/09 04:00:00+00
# 78   -85.488744  0.0        79   GO-2004120070  2004/01/03 05:00:00+00
# 112  -85.488744  0.0       113   GO-2004692390  2004/10/23 04:00:00+00
# ...         ...  ...       ...             ...                     ...
# 2184 -85.488744  0.0      2185  GO-20134907315  2013/03/28 04:00:00+00
# 2223 -85.488744  0.0      2224  GO-20135154184  2013/10/03 04:00:00+00
# 2250 -85.488744  0.0      2251  GO-20135164075  2013/08/21 04:00:00+00
# 2258 -85.488744  0.0      2259  GO-20135072874  2013/07/01 04:00:00+00
# 2259 -85.488744  0.0      2260  GO-20134785610  2013/01/16 05:00:00+00
#
#       OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 9         2004    October     Friday      289       15  ...       Afternoon  \
# 22        2004  September     Friday      247        3  ...       Afternoon
# 27        2004       July     Friday      191        9  ...         Morning
# 78        2004    January   Saturday        3        3  ...           Night
# 112       2004    October   Saturday      297       23  ...           Night
# ...        ...        ...        ...      ...      ...  ...             ...
# 2184      2013      March   Thursday       87       28  ...           Night
# 2223      2013    October   Thursday      276        3  ...           Night
# 2250      2013     August  Wednesday      233       21  ...           Night
# 2258      2013       July     Monday      182        1  ...       Afternoon
# 2259      2013    January  Wednesday       16       16  ...         Evening
#
#      DIVISION DEATH  INJURIES  HOOD_158 NEIGHBOURHOOD_158 HOOD_140
# 9         D31     1         0       NSA               NSA      NSA  \
# 22        D51     0         1       NSA               NSA      NSA
# 27        D14     0         0       NSA               NSA      NSA
# 78        D54     0         0       NSA               NSA      NSA
# 112       D14     0         1       NSA               NSA      NSA
# ...       ...   ...       ...       ...               ...      ...
# 2184      D14     1         1       NSA               NSA      NSA
# 2223      D12     0         1       NSA               NSA      NSA
# 2250      D51     0         1       NSA               NSA      NSA
# 2258      D42     0         1       NSA               NSA      NSA
# 2259      D23     0         1       NSA               NSA      NSA
#
#      NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 9                  NSA -85.488744        0.0
# 22                 NSA -85.488744        0.0
# 27                 NSA -85.488744        0.0
# 78                 NSA -85.488744        0.0
# 112                NSA -85.488744        0.0
# ...                ...        ...        ...
# 2184               NSA -85.488744        0.0
# 2223               NSA -85.488744        0.0
# 2250               NSA -85.488744        0.0
# 2258               NSA -85.488744        0.0
# 2259               NSA -85.488744        0.0
#
# [62 rows x 21 columns]

# %% [markdown]
# Creating our "clean" dataset by including only non-0 Y value entries and setting that to df2.

# %%
df2 = df[df['Y']!= 0]

# %% [markdown]
# Check for any duplicate entries:

# %%
df2.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5702    False
# 5703    False
# 5704    False
# 5705    False
# 5706    False
# Length: 5645, dtype: bool

# %% [markdown]
# Going to check for NSA values in HOOD_140 to review how to possibly fill missing values.

# %%
df2[df2['HOOD_140'] == 'NSA']
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 232  -79.543821  43.772941       233  GO-20051440086  2005/12/01 05:00:00+00  \
# 582  -79.603380  43.757866       583  GO-20061567864  2006/04/15 04:00:00+00
# 4648 -79.574871  43.764348      4649  GO-20201624652  2020/08/28 04:00:00+00
# 5031 -79.574871  43.764348      5032     GO-20214289  2021/01/07 05:00:00+00
#
#       OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 232       2005  December  Thursday      335        1  ...         Evening  \
# 582       2006     April  Saturday      105       15  ...         Evening
# 4648      2020    August    Friday      241       28  ...       Afternoon
# 5031      2021   January  Thursday        7        7  ...         Evening
#
#      DIVISION DEATH  INJURIES  HOOD_158 NEIGHBOURHOOD_158 HOOD_140
# 232       D31     1         0       NSA               NSA      NSA  \
# 582       D23     0         1       NSA               NSA      NSA
# 4648      D31     0         1        21     Humber Summit      NSA
# 5031      D31     0         0        21     Humber Summit      NSA
#
#      NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 232                NSA -79.543821  43.772941
# 582                NSA -79.603380  43.757866
# 4648               NSA -79.574871  43.764348
# 5031               NSA -79.574871  43.764348
#
# [4 rows x 21 columns]

# %% [markdown]
# Checking the same thing for NEIGHBOURHOOD_140

# %%
df2[df2['NEIGHBOURHOOD_140'] == 'NSA']
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 232  -79.543821  43.772941       233  GO-20051440086  2005/12/01 05:00:00+00  \
# 582  -79.603380  43.757866       583  GO-20061567864  2006/04/15 04:00:00+00
# 4648 -79.574871  43.764348      4649  GO-20201624652  2020/08/28 04:00:00+00
# 5031 -79.574871  43.764348      5032     GO-20214289  2021/01/07 05:00:00+00
#
#       OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 232       2005  December  Thursday      335        1  ...         Evening  \
# 582       2006     April  Saturday      105       15  ...         Evening
# 4648      2020    August    Friday      241       28  ...       Afternoon
# 5031      2021   January  Thursday        7        7  ...         Evening
#
#      DIVISION DEATH  INJURIES  HOOD_158 NEIGHBOURHOOD_158 HOOD_140
# 232       D31     1         0       NSA               NSA      NSA  \
# 582       D23     0         1       NSA               NSA      NSA
# 4648      D31     0         1        21     Humber Summit      NSA
# 5031      D31     0         0        21     Humber Summit      NSA
#
#      NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 232                NSA -79.543821  43.772941
# 582                NSA -79.603380  43.757866
# 4648               NSA -79.574871  43.764348
# 5031               NSA -79.574871  43.764348
#
# [4 rows x 21 columns]

# %% [markdown]
# Setting the missing HOOD_140 & NEIGHBOURHOOD_140 data with the available HOOD_158 and NEIGHBOURHOOD_158 data equivalent.

# %%
df2.loc[df['OBJECTID'].isin([4649, 5032]), 'NEIGHBOURHOOD_140'] = 'Humber Summit (21)'

# %%
df2.loc[df['OBJECTID'].isin([4649, 5032]), 'HOOD_140'] = 21

# %%
df2[df2['NEIGHBOURHOOD_140'] == 'NSA']
# Out:
#              X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 232 -79.543821  43.772941       233  GO-20051440086  2005/12/01 05:00:00+00  \
# 582 -79.603380  43.757866       583  GO-20061567864  2006/04/15 04:00:00+00
#
#      OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 232      2005  December  Thursday      335        1  ...         Evening  \
# 582      2006     April  Saturday      105       15  ...         Evening
#
#     DIVISION DEATH  INJURIES  HOOD_158 NEIGHBOURHOOD_158 HOOD_140
# 232      D31     1         0       NSA               NSA      NSA  \
# 582      D23     0         1       NSA               NSA      NSA
#
#     NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 232               NSA -79.543821  43.772941
# 582               NSA -79.603380  43.757866
#
# [2 rows x 21 columns]

# %% [markdown]
# Attempted to use the HOOD_140 lat and long range to determine what the missing HOOD values are:

# %%
range_data = df2.groupby('HOOD_140').agg({'LONG_WGS84': ['min', 'max'], 'LAT_WGS84': ['min', 'max']})

# %%
range_data.columns = ['LAT_min', 'LAT_max', 'LONG_min', 'LONG_max']

# %%
print(range_data)
# Out:
#             LAT_min    LAT_max   LONG_min   LONG_max
# HOOD_140
# 21       -79.574871 -79.574871  43.764348  43.764348
# 1        -79.625565 -79.554963  43.672241  43.756545
# 10       -79.557109 -79.543490  43.664777  43.674982
# 100      -79.408512 -79.403318  43.697921  43.704592
# 101      -79.407207 -79.407207  43.692034  43.692034
# ...             ...        ...        ...        ...
# 96       -79.418298 -79.415783  43.676724  43.683387
# 97       -79.397258 -79.393774  43.680943  43.694651
# 98       -79.392756 -79.368196  43.671040  43.693791
# 99       -79.391776 -79.378041  43.708648  43.712600
# NSA      -79.603380 -79.543821  43.757866  43.772941
#
# [141 rows x 4 columns]

# %% [markdown]
# SEARCHING TO FIND WHAT HOOD THIS MISSING DATA BELONGS TO USING LAT AND LONG INFO

# %%
search_lat = 43.757866
search_long = -79.603380

# %%
filtered_data = df2[(df2['LAT_WGS84'] == search_lat) & (df2['LONG_WGS84'] == search_long)]

# %%
if not filtered_data.empty:
    hood_140 = filtered_data['HOOD_140'].iloc[0]
    print("The row belongs to HOOD_140:", hood_140)
else:
    print("No matching row found.")
# Out:
# No matching row found.

# %% [markdown]
# Neither resulted in anything, so we'll drop this data as it's not overly necessary.

# %%
df2[df2['HOOD_140'] == 'NSA']
# Out:
#              X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 232 -79.543821  43.772941       233  GO-20051440086  2005/12/01 05:00:00+00  \
# 582 -79.603380  43.757866       583  GO-20061567864  2006/04/15 04:00:00+00
#
#      OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 232      2005  December  Thursday      335        1  ...         Evening  \
# 582      2006     April  Saturday      105       15  ...         Evening
#
#     DIVISION DEATH  INJURIES  HOOD_158 NEIGHBOURHOOD_158 HOOD_140
# 232      D31     1         0       NSA               NSA      NSA  \
# 582      D23     0         1       NSA               NSA      NSA
#
#     NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 232               NSA -79.543821  43.772941
# 582               NSA -79.603380  43.757866
#
# [2 rows x 21 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5645 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5645 non-null   float64
#  1   Y                  5645 non-null   float64
#  2   OBJECTID           5645 non-null   int64
#  3   EVENT_UNIQUE_ID    5645 non-null   object
#  4   OCC_DATE           5645 non-null   object
#  5   OCC_YEAR           5645 non-null   int64
#  6   OCC_MONTH          5645 non-null   object
#  7   OCC_DOW            5645 non-null   object
#  8   OCC_DOY            5645 non-null   int64
#  9   OCC_DAY            5645 non-null   int64
#  10  OCC_HOUR           5645 non-null   int64
#  11  OCC_TIME_RANGE     5645 non-null   object
#  12  DIVISION           5645 non-null   object
#  13  DEATH              5645 non-null   int64
#  14  INJURIES           5645 non-null   int64
#  15  HOOD_158           5645 non-null   object
#  16  NEIGHBOURHOOD_158  5645 non-null   object
#  17  HOOD_140           5645 non-null   object
#  18  NEIGHBOURHOOD_140  5645 non-null   object
#  19  LONG_WGS84         5645 non-null   float64
#  20  LAT_WGS84          5645 non-null   float64
# dtypes: float64(4), int64(7), object(10)
# memory usage: 970.2+ KB

# %% [markdown]
# We're going to drop the remaining 2 entries with NSA HOOD_140 data.

# %%
df2 = df2.drop(df2[df2['HOOD_140'] == 'NSA'].index)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5643 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5643 non-null   float64
#  1   Y                  5643 non-null   float64
#  2   OBJECTID           5643 non-null   int64
#  3   EVENT_UNIQUE_ID    5643 non-null   object
#  4   OCC_DATE           5643 non-null   object
#  5   OCC_YEAR           5643 non-null   int64
#  6   OCC_MONTH          5643 non-null   object
#  7   OCC_DOW            5643 non-null   object
#  8   OCC_DOY            5643 non-null   int64
#  9   OCC_DAY            5643 non-null   int64
#  10  OCC_HOUR           5643 non-null   int64
#  11  OCC_TIME_RANGE     5643 non-null   object
#  12  DIVISION           5643 non-null   object
#  13  DEATH              5643 non-null   int64
#  14  INJURIES           5643 non-null   int64
#  15  HOOD_158           5643 non-null   object
#  16  NEIGHBOURHOOD_158  5643 non-null   object
#  17  HOOD_140           5643 non-null   object
#  18  NEIGHBOURHOOD_140  5643 non-null   object
#  19  LONG_WGS84         5643 non-null   float64
#  20  LAT_WGS84          5643 non-null   float64
# dtypes: float64(4), int64(7), object(10)
# memory usage: 969.9+ KB

# %% [markdown]
# Going to create a separate variable/column named TOTAL_CASUALTIES to see the total casualties involved in each shooting incident.

# %%
df2.insert(df2.columns.get_loc('INJURIES') + 1, 'TOTAL_CASUALTIES', df2['DEATH'] + df2['INJURIES'])

# %%
df2
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5702 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5703 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5704 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5705 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5706 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
#       OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  DIVISION DEATH
# 0         2004        May   Saturday      136       15  ...       D41     0  \
# 1         2004       July     Monday      208       26  ...       D23     0
# 2         2004        May     Friday      135       14  ...       D31     1
# 3         2004   December     Sunday      354       19  ...       D51     1
# 4         2004      April     Monday      103       12  ...       D42     0
# ...        ...        ...        ...      ...      ...  ...       ...   ...
# 5702      2022       June   Thursday      153        2  ...       D33     0
# 5703      2022       July     Sunday      198       17  ...       D14     1
# 5704      2022   February     Monday       52       21  ...       D43     0
# 5705      2022  September     Sunday      254       11  ...       D11     0
# 5706      2022      April  Wednesday      117       27  ...       D51     0
#
#      INJURIES  TOTAL_CASUALTIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0           0                 0       142            Woburn North      137  \
# 1           0                 0         1  West Humber-Clairville        1
# 2           1                 2        24             Black Creek       24
# 3           0                 1       168     Downtown Yonge East       75
# 4           0                 0       146            Malvern East      132
# ...       ...               ...       ...                     ...      ...
# 5702        1                 1        53              Henry Farm       53
# 5703        1                 2       164        Wellington Place       77
# 5704        0                 0       135             Morningside      135
# 5705        2                 2        83          Dufferin Grove       83
# 5706        0                 0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                               Woburn (137) -79.234955  43.781528
# 1                 West Humber-Clairville (1) -79.618218  43.733547
# 2                           Black Creek (24) -79.518759  43.769157
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665
# 4                              Malvern (132) -79.212435  43.812075
# ...                                      ...        ...        ...
# 5702                         Henry Farm (53) -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920
# 5704                       Morningside (135) -79.196217  43.786621
# 5705                     Dufferin Grove (83) -79.443993  43.658083
# 5706                          Moss Park (73) -79.369456  43.654519
#
# [5643 rows x 22 columns]

# %% [markdown]
# We're going to drop the X and Y columns as they are simply repeats of the Latitude and Longitude columns.

# %%
df2.drop('X', axis=1, inplace=True)

# %%
df2.drop('Y', axis=1, inplace=True)

# %%
df2
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR  OCC_MONTH
# 0            1   GO-2004397105  2004/05/15 04:00:00+00      2004        May  \
# 1            2   GO-2004600109  2004/07/26 04:00:00+00      2004       July
# 2            3   GO-2004311851  2004/05/14 04:00:00+00      2004        May
# 3            4   GO-2004736004  2004/12/19 05:00:00+00      2004   December
# 4            5   GO-2004303455  2004/04/12 04:00:00+00      2004      April
# ...        ...             ...                     ...       ...        ...
# 5702      5703  GO-20221038418  2022/06/02 04:00:00+00      2022       June
# 5703      5704  GO-20221362949  2022/07/17 04:00:00+00      2022       July
# 5704      5705   GO-2022336423  2022/02/21 05:00:00+00      2022   February
# 5705      5706  GO-20221765442  2022/09/11 04:00:00+00      2022  September
# 5706      5707   GO-2022783839  2022/04/27 04:00:00+00      2022      April
#
#         OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE DIVISION  DEATH
# 0      Saturday      136       15         1          Night      D41      0  \
# 1        Monday      208       26        23        Evening      D23      0
# 2        Friday      135       14        16      Afternoon      D31      1
# 3        Sunday      354       19         0          Night      D51      1
# 4        Monday      103       12        22        Evening      D42      0
# ...         ...      ...      ...       ...            ...      ...    ...
# 5702   Thursday      153        2         3          Night      D33      0
# 5703     Sunday      198       17         3          Night      D14      1
# 5704     Monday       52       21         5          Night      D43      0
# 5705     Sunday      254       11         1          Night      D11      0
# 5706  Wednesday      117       27        17      Afternoon      D51      0
#
#       INJURIES  TOTAL_CASUALTIES HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0            0                 0      142            Woburn North      137  \
# 1            0                 0        1  West Humber-Clairville        1
# 2            1                 2       24             Black Creek       24
# 3            0                 1      168     Downtown Yonge East       75
# 4            0                 0      146            Malvern East      132
# ...        ...               ...      ...                     ...      ...
# 5702         1                 1       53              Henry Farm       53
# 5703         1                 2      164        Wellington Place       77
# 5704         0                 0      135             Morningside      135
# 5705         2                 2       83          Dufferin Grove       83
# 5706         0                 0       73               Moss Park       73
#
#                            NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0                               Woburn (137)  -79.234955  43.781528
# 1                 West Humber-Clairville (1)  -79.618218  43.733547
# 2                           Black Creek (24)  -79.518759  43.769157
# 3                 Church-Yonge Corridor (75)  -79.378870  43.660665
# 4                              Malvern (132)  -79.212435  43.812075
# ...                                      ...         ...        ...
# 5702                         Henry Farm (53)  -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77)  -79.402702  43.643920
# 5704                       Morningside (135)  -79.196217  43.786621
# 5705                     Dufferin Grove (83)  -79.443993  43.658083
# 5706                          Moss Park (73)  -79.369456  43.654519
#
# [5643 rows x 20 columns]

# %% [markdown]
# We're going to group some data and chart some data to review what the remaining data tells us about our variables of interest.

# %%
grouped_hood = df2.groupby('HOOD_140')['TOTAL_CASUALTIES'].sum()

# %%
plt.figure(figsize=(18, 6))
grouped_hood.plot(kind='bar')
plt.xlabel('HOOD_140')
plt.ylabel('Total Casualties')
plt.title('Total Casualties by HOOD_140')
plt.xticks(rotation=90)
plt.show()

# %%
grouped_division = df2.groupby('DIVISION')['TOTAL_CASUALTIES'].sum()

# %%
plt.figure(figsize=(18, 6))
grouped_division.plot(kind='bar')
plt.xlabel('DIVISION')
plt.ylabel('Total Casualties')
plt.title('Total Casualties by DIVISION')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data = grouped_hood)
# Out:
# <Axes: xlabel='HOOD_140', ylabel='TOTAL_CASUALTIES'>

# %% [markdown]
# Noticed specific neighbourhood had significantly higher casualties than others. We will single this neighbourhood out to review that data and ensure it makes sense.

# %%
filtered_hood = grouped_hood[grouped_hood > 150]
print(filtered_hood)
# Out:
# HOOD_140
# 25    164
# Name: TOTAL_CASUALTIES, dtype: int64

# %%
df2[df2['HOOD_140'] == '25']
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR OCC_MONTH
# 72          73   GO-2004602734  2004/07/13 04:00:00+00      2004      July  \
# 83          84   GO-2004388577  2004/05/12 04:00:00+00      2004       May
# 98          99   GO-2004310859  2004/04/15 04:00:00+00      2004     April
# 170        171   GO-2004629200  2004/08/17 04:00:00+00      2004    August
# 186        187   GO-2004387646  2004/05/13 04:00:00+00      2004       May
# ...        ...             ...                     ...       ...       ...
# 5480      5481    GO-202230928  2022/01/05 05:00:00+00      2022   January
# 5524      5525   GO-2022210012  2022/02/01 05:00:00+00      2022  February
# 5551      5552  GO-20221669419  2022/08/29 04:00:00+00      2022    August
# 5654      5655  GO-20221946068  2022/10/06 04:00:00+00      2022   October
# 5682      5683   GO-2022514139  2022/03/19 04:00:00+00      2022     March
#
#         OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE DIVISION  DEATH
# 72      Tuesday      195       13        17      Afternoon      D31      0  \
# 83    Wednesday      133       12         0          Night      D31      0
# 98     Thursday      106       15         0          Night      D31      0
# 170     Tuesday      230       17         1          Night      D31      0
# 186    Thursday      134       13        16      Afternoon      D31      0
# ...         ...      ...      ...       ...            ...      ...    ...
# 5480  Wednesday        5        5        22        Evening      D31      0
# 5524    Tuesday       32        1        11        Morning      D31      0
# 5551     Monday      241       29         1          Night      D31      0
# 5654   Thursday      279        6        13      Afternoon      D31      1
# 5682   Saturday       78       19        13      Afternoon      D31      0
#
#       INJURIES  TOTAL_CASUALTIES HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 72           1                 1       25  Glenfield-Jane Heights       25  \
# 83           0                 0       25  Glenfield-Jane Heights       25
# 98           2                 2       25  Glenfield-Jane Heights       25
# 170          1                 1       25  Glenfield-Jane Heights       25
# 186          0                 0       25  Glenfield-Jane Heights       25
# ...        ...               ...      ...                     ...      ...
# 5480         1                 1       25  Glenfield-Jane Heights       25
# 5524         1                 1       25  Glenfield-Jane Heights       25
# 5551         0                 0       25  Glenfield-Jane Heights       25
# 5654         0                 1       25  Glenfield-Jane Heights       25
# 5682         0                 0       25  Glenfield-Jane Heights       25
#
#                 NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 72    Glenfield-Jane Heights (25)  -79.508172  43.743052
# 83    Glenfield-Jane Heights (25)  -79.508729  43.756383
# 98    Glenfield-Jane Heights (25)  -79.510446  43.749221
# 170   Glenfield-Jane Heights (25)  -79.517071  43.754848
# 186   Glenfield-Jane Heights (25)  -79.519235  43.752866
# ...                           ...         ...        ...
# 5480  Glenfield-Jane Heights (25)  -79.517094  43.752424
# 5524  Glenfield-Jane Heights (25)  -79.511595  43.742126
# 5551  Glenfield-Jane Heights (25)  -79.529087  43.748417
# 5654  Glenfield-Jane Heights (25)  -79.519235  43.752866
# 5682  Glenfield-Jane Heights (25)  -79.509120  43.758127
#
# [304 rows x 20 columns]

# %% [markdown]
# We will now review the data types and ensure they are all correct, and fix those that are not.

# %%
df2.dtypes
# Out:
# OBJECTID               int64
# EVENT_UNIQUE_ID       object
# OCC_DATE              object
# OCC_YEAR               int64
# OCC_MONTH             object
# OCC_DOW               object
# OCC_DOY                int64
# OCC_DAY                int64
# OCC_HOUR               int64
# OCC_TIME_RANGE        object
# DIVISION              object
# DEATH                  int64
# INJURIES               int64
# TOTAL_CASUALTIES       int64
# HOOD_158              object
# NEIGHBOURHOOD_158     object
# HOOD_140              object
# NEIGHBOURHOOD_140     object
# LONG_WGS84           float64
# LAT_WGS84            float64
# dtype: object

# %% [markdown]
# Both HOOD columns are objects but they should be integers. We will go ahead and switch those over to integers to make future use of the data easier.

# %%
df2['HOOD_140'] = df2['HOOD_140'].astype(int)
df2['HOOD_158'] = df2['HOOD_158'].astype(int)

# %%
df2.dtypes
# Out:
# OBJECTID               int64
# EVENT_UNIQUE_ID       object
# OCC_DATE              object
# OCC_YEAR               int64
# OCC_MONTH             object
# OCC_DOW               object
# OCC_DOY                int64
# OCC_DAY                int64
# OCC_HOUR               int64
# OCC_TIME_RANGE        object
# DIVISION              object
# DEATH                  int64
# INJURIES               int64
# TOTAL_CASUALTIES       int64
# HOOD_158               int64
# NEIGHBOURHOOD_158     object
# HOOD_140               int64
# NEIGHBOURHOOD_140     object
# LONG_WGS84           float64
# LAT_WGS84            float64
# dtype: object

# %% [markdown]
# Checking to make sure no more NSA values appear in any part of the data.

# %%
contains_nsa = df2.applymap(lambda x: 'NSA' in str(x)).any()

print(contains_nsa)
# Out:
# OBJECTID             False
# EVENT_UNIQUE_ID      False
# OCC_DATE             False
# OCC_YEAR             False
# OCC_MONTH            False
# OCC_DOW              False
# OCC_DOY              False
# OCC_DAY              False
# OCC_HOUR             False
# OCC_TIME_RANGE       False
# DIVISION             False
# DEATH                False
# INJURIES             False
# TOTAL_CASUALTIES     False
# HOOD_158             False
# NEIGHBOURHOOD_158    False
# HOOD_140             False
# NEIGHBOURHOOD_140    False
# LONG_WGS84           False
# LAT_WGS84            False
# dtype: bool

# %% [markdown]
# All result in false, and thus no NSA values remain.

# %% [markdown]
# We will now review the LAT and LONG data using Z-Score analysis to find any strange geo-location data in the data set.

# %%
import numpy as np

# Calculate z-scores for latitude and longitude
zscore_latitude = np.abs((df2['LAT_WGS84'] - df2['LAT_WGS84'].mean()) / df2['LAT_WGS84'].std())
zscore_longitude = np.abs((df2['LONG_WGS84'] - df2['LONG_WGS84'].mean()) / df2['LONG_WGS84'].std())

# Set a threshold for z-score to identify outliers
threshold = 2.6

# Find rows where either latitude or longitude is an outlier
outliers = df2[(zscore_latitude > threshold) | (zscore_longitude > threshold)]

# Print the outlier rows
print(outliers)
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR OCC_MONTH
# 3269      3270  GO-20171504990  2017/08/20 04:00:00+00      2017    August  \
# 5187      5188  GO-20212517884  2021/12/30 05:00:00+00      2021  December
#
#        OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE DIVISION  DEATH
# 3269    Sunday      232       20        12      Afternoon      D22      0  \
# 5187  Thursday      364       30        18        Evening      D22      0
#
#       INJURIES  TOTAL_CASUALTIES  HOOD_158 NEIGHBOURHOOD_158  HOOD_140
# 3269         0                 0        19       Long Branch        19  \
# 5187         1                 1        19       Long Branch        19
#
#      NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 3269  Long Branch (19)  -79.538412  43.590860
# 5187  Long Branch (19)  -79.541863  43.587343

# %% [markdown]
# We have decided to leave these two locations alone as they are not significantly out of the normal range and thus likely represent legitimate location data.

# %%
df2
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR  OCC_MONTH
# 0            1   GO-2004397105  2004/05/15 04:00:00+00      2004        May  \
# 1            2   GO-2004600109  2004/07/26 04:00:00+00      2004       July
# 2            3   GO-2004311851  2004/05/14 04:00:00+00      2004        May
# 3            4   GO-2004736004  2004/12/19 05:00:00+00      2004   December
# 4            5   GO-2004303455  2004/04/12 04:00:00+00      2004      April
# ...        ...             ...                     ...       ...        ...
# 5702      5703  GO-20221038418  2022/06/02 04:00:00+00      2022       June
# 5703      5704  GO-20221362949  2022/07/17 04:00:00+00      2022       July
# 5704      5705   GO-2022336423  2022/02/21 05:00:00+00      2022   February
# 5705      5706  GO-20221765442  2022/09/11 04:00:00+00      2022  September
# 5706      5707   GO-2022783839  2022/04/27 04:00:00+00      2022      April
#
#         OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE DIVISION  DEATH
# 0      Saturday      136       15         1          Night      D41      0  \
# 1        Monday      208       26        23        Evening      D23      0
# 2        Friday      135       14        16      Afternoon      D31      1
# 3        Sunday      354       19         0          Night      D51      1
# 4        Monday      103       12        22        Evening      D42      0
# ...         ...      ...      ...       ...            ...      ...    ...
# 5702   Thursday      153        2         3          Night      D33      0
# 5703     Sunday      198       17         3          Night      D14      1
# 5704     Monday       52       21         5          Night      D43      0
# 5705     Sunday      254       11         1          Night      D11      0
# 5706  Wednesday      117       27        17      Afternoon      D51      0
#
#       INJURIES  TOTAL_CASUALTIES  HOOD_158       NEIGHBOURHOOD_158  HOOD_140
# 0            0                 0       142            Woburn North       137  \
# 1            0                 0         1  West Humber-Clairville         1
# 2            1                 2        24             Black Creek        24
# 3            0                 1       168     Downtown Yonge East        75
# 4            0                 0       146            Malvern East       132
# ...        ...               ...       ...                     ...       ...
# 5702         1                 1        53              Henry Farm        53
# 5703         1                 2       164        Wellington Place        77
# 5704         0                 0       135             Morningside       135
# 5705         2                 2        83          Dufferin Grove        83
# 5706         0                 0        73               Moss Park        73
#
#                            NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0                               Woburn (137)  -79.234955  43.781528
# 1                 West Humber-Clairville (1)  -79.618218  43.733547
# 2                           Black Creek (24)  -79.518759  43.769157
# 3                 Church-Yonge Corridor (75)  -79.378870  43.660665
# 4                              Malvern (132)  -79.212435  43.812075
# ...                                      ...         ...        ...
# 5702                         Henry Farm (53)  -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77)  -79.402702  43.643920
# 5704                       Morningside (135)  -79.196217  43.786621
# 5705                     Dufferin Grove (83)  -79.443993  43.658083
# 5706                          Moss Park (73)  -79.369456  43.654519
#
# [5643 rows x 20 columns]

# %% [markdown]
# We will now create a 'SEASON' column to review what season each incident took place in. To do this, we will set a DOY range to correspond with the DOY season range provided by the government of Canada website. We will then use the DOY value of each incident to be able to give the incident it's corresponding 'SEASON' value.

# %%
conditions = [
    (df2['OCC_DOY'].between(172, 264)),  # Summer
    (df2['OCC_DOY'].between(265, 354)),  # Fall
    (df2['OCC_DOY'].between(355, 366)) | (df2['OCC_DOY'].between(0, 78)),  # Winter
    (df2['OCC_DOY'].between(79, 171))  # Spring
]

seasons = ['Summer', 'Fall', 'Winter', 'Spring']

df2['SEASON'] = np.select(conditions, seasons, default=pd.NA)

print(df2)
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR  OCC_MONTH
# 0            1   GO-2004397105  2004/05/15 04:00:00+00      2004        May  \
# 1            2   GO-2004600109  2004/07/26 04:00:00+00      2004       July
# 2            3   GO-2004311851  2004/05/14 04:00:00+00      2004        May
# 3            4   GO-2004736004  2004/12/19 05:00:00+00      2004   December
# 4            5   GO-2004303455  2004/04/12 04:00:00+00      2004      April
# ...        ...             ...                     ...       ...        ...
# 5702      5703  GO-20221038418  2022/06/02 04:00:00+00      2022       June
# 5703      5704  GO-20221362949  2022/07/17 04:00:00+00      2022       July
# 5704      5705   GO-2022336423  2022/02/21 05:00:00+00      2022   February
# 5705      5706  GO-20221765442  2022/09/11 04:00:00+00      2022  September
# 5706      5707   GO-2022783839  2022/04/27 04:00:00+00      2022      April
#
#         OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE  ... DEATH
# 0      Saturday      136       15         1          Night  ...     0  \
# 1        Monday      208       26        23        Evening  ...     0
# 2        Friday      135       14        16      Afternoon  ...     1
# 3        Sunday      354       19         0          Night  ...     1
# 4        Monday      103       12        22        Evening  ...     0
# ...         ...      ...      ...       ...            ...  ...   ...
# 5702   Thursday      153        2         3          Night  ...     0
# 5703     Sunday      198       17         3          Night  ...     1
# 5704     Monday       52       21         5          Night  ...     0
# 5705     Sunday      254       11         1          Night  ...     0
# 5706  Wednesday      117       27        17      Afternoon  ...     0
#
#       INJURIES  TOTAL_CASUALTIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0            0                 0       142            Woburn North      137  \
# 1            0                 0         1  West Humber-Clairville        1
# 2            1                 2        24             Black Creek       24
# 3            0                 1       168     Downtown Yonge East       75
# 4            0                 0       146            Malvern East      132
# ...        ...               ...       ...                     ...      ...
# 5702         1                 1        53              Henry Farm       53
# 5703         1                 2       164        Wellington Place       77
# 5704         0                 0       135             Morningside      135
# 5705         2                 2        83          Dufferin Grove       83
# 5706         0                 0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84  SEASON
# 0                               Woburn (137) -79.234955  43.781528  Spring
# 1                 West Humber-Clairville (1) -79.618218  43.733547  Summer
# 2                           Black Creek (24) -79.518759  43.769157  Spring
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665    Fall
# 4                              Malvern (132) -79.212435  43.812075  Spring
# ...                                      ...        ...        ...     ...
# 5702                         Henry Farm (53) -79.362941  43.771764  Spring
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920  Summer
# 5704                       Morningside (135) -79.196217  43.786621  Winter
# 5705                     Dufferin Grove (83) -79.443993  43.658083  Summer
# 5706                          Moss Park (73) -79.369456  43.654519  Spring
#
# [5643 rows x 21 columns]

# %%
df2
# Out:
#       OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR  OCC_MONTH
# 0            1   GO-2004397105  2004/05/15 04:00:00+00      2004        May  \
# 1            2   GO-2004600109  2004/07/26 04:00:00+00      2004       July
# 2            3   GO-2004311851  2004/05/14 04:00:00+00      2004        May
# 3            4   GO-2004736004  2004/12/19 05:00:00+00      2004   December
# 4            5   GO-2004303455  2004/04/12 04:00:00+00      2004      April
# ...        ...             ...                     ...       ...        ...
# 5702      5703  GO-20221038418  2022/06/02 04:00:00+00      2022       June
# 5703      5704  GO-20221362949  2022/07/17 04:00:00+00      2022       July
# 5704      5705   GO-2022336423  2022/02/21 05:00:00+00      2022   February
# 5705      5706  GO-20221765442  2022/09/11 04:00:00+00      2022  September
# 5706      5707   GO-2022783839  2022/04/27 04:00:00+00      2022      April
#
#         OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE  ... DEATH
# 0      Saturday      136       15         1          Night  ...     0  \
# 1        Monday      208       26        23        Evening  ...     0
# 2        Friday      135       14        16      Afternoon  ...     1
# 3        Sunday      354       19         0          Night  ...     1
# 4        Monday      103       12        22        Evening  ...     0
# ...         ...      ...      ...       ...            ...  ...   ...
# 5702   Thursday      153        2         3          Night  ...     0
# 5703     Sunday      198       17         3          Night  ...     1
# 5704     Monday       52       21         5          Night  ...     0
# 5705     Sunday      254       11         1          Night  ...     0
# 5706  Wednesday      117       27        17      Afternoon  ...     0
#
#       INJURIES  TOTAL_CASUALTIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0            0                 0       142            Woburn North      137  \
# 1            0                 0         1  West Humber-Clairville        1
# 2            1                 2        24             Black Creek       24
# 3            0                 1       168     Downtown Yonge East       75
# 4            0                 0       146            Malvern East      132
# ...        ...               ...       ...                     ...      ...
# 5702         1                 1        53              Henry Farm       53
# 5703         1                 2       164        Wellington Place       77
# 5704         0                 0       135             Morningside      135
# 5705         2                 2        83          Dufferin Grove       83
# 5706         0                 0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84  SEASON
# 0                               Woburn (137) -79.234955  43.781528  Spring
# 1                 West Humber-Clairville (1) -79.618218  43.733547  Summer
# 2                           Black Creek (24) -79.518759  43.769157  Spring
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665    Fall
# 4                              Malvern (132) -79.212435  43.812075  Spring
# ...                                      ...        ...        ...     ...
# 5702                         Henry Farm (53) -79.362941  43.771764  Spring
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920  Summer
# 5704                       Morningside (135) -79.196217  43.786621  Winter
# 5705                     Dufferin Grove (83) -79.443993  43.658083  Summer
# 5706                          Moss Park (73) -79.369456  43.654519  Spring
#
# [5643 rows x 21 columns]

# %% [markdown]
# We will now review the data grouped based on season to ensure all the data makes sense and to see the impact season may have on TOTAL_CASUALTIES.

# %%
grouped_season = df2.groupby('SEASON')['TOTAL_CASUALTIES'].sum()

# %%
print(grouped_season)
# Out:
# SEASON
# Fall       806
# Spring     816
# Summer    1089
# Winter     728
# Name: TOTAL_CASUALTIES, dtype: int64

# %%
grouped_season.plot(kind = 'bar')
plt.xlabel('Season')
plt.ylabel('Total number of casualties')
plt.show()

# %% [markdown]
# We now believe all the cleaning and data transforming is enough to meet our needs and will now export the DataFrame into a CSV file.

# %%
#df2.to_csv('/Users/mikeredshaw/Documents/AI_PROJECT_DATA_CLEAN5.csv', encoding='utf-8', index=True, header=True)

# %%
dfn = pd.read_csv('/Users/mikeredshaw/Documents/Schulich MBAN/MMAI 5000 AI Fundamentals/Neighbourhood_Clean_Data-Final.csv')

# %%
dfn['HOOD_140'] = dfn['0']

# %%
dfn.head()
# Out:
#    Unnamed: 0.1                    Unnamed: 0                     0
# 0             0                Characteristic  Neighbourhood Number  \
# 1             1               City of Toronto                   NaN
# 2             2               Agincourt North                 129.0
# 3             3  Agincourt South-Malvern West                 128.0
# 4             4                     Alderwood                  20.0
#
#             85           86           87                   88          1886
# 0    2 persons    3 persons    4 persons    5 or more persons      Employed  \
# 1     344110.0     174600.0     143250.0              56795.0     1361375.0
# 2       3570.0       2390.0       1875.0                605.0       12510.0
# 3       2970.0       1835.0       1325.0                520.0       10855.0
# 4       1605.0        900.0        755.0                220.0        6405.0
#
#              1887  Under $50,000  $50,000 - $100,000  $100,000 and over
# 0      Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over  \
# 1        122305.0       386930.0            342375.0           343520.0
# 2          1360.0         3310.0              3175.0             2505.0
# 3          1185.0         2975.0              2925.0             2030.0
# 4           415.0         1240.0              1480.0             1915.0
#
#    $200,000 and over  Post Secondary Degree  Bachelor level or above
# 0  $200,000 and over  Post Secondary Degree  Bachelor level or above  \
# 1            96600.0               468040.0                1424440.0
# 2              325.0                 4690.0                  10480.0
# 3              285.0                 4130.0                  10255.0
# 4              360.0                 2670.0                   4075.0
#
#                                        NO EDU
# 0    No certificate, diploma or degree-NO EDU  \
# 1                                    377340.0
# 2                                      6550.0
# 3                                      4035.0
# 4                                      2005.0
#
#                       Secondary school or equivalent
# 0    Secondary (high) school diploma or equivalen...  \
# 1                                           561090.0
# 2                                             7460.0
# 3                                             6090.0
# 4                                             2960.0
#
#                                   Trades certificate              HOOD_140
# 0        Trades certificate or diploma other than...  Neighbourhood Number
# 1                                            53060.0                   NaN
# 2                                              505.0                 129.0
# 3                                              375.0                 128.0
# 4                                              345.0                  20.0

# %%
dfn['HOOD_140'] = dfn['HOOD_140'].fillna('0')

# %%
dfn.head()
# Out:
#    Unnamed: 0.1                    Unnamed: 0                     0
# 0             0                Characteristic  Neighbourhood Number  \
# 1             1               City of Toronto                   NaN
# 2             2               Agincourt North                 129.0
# 3             3  Agincourt South-Malvern West                 128.0
# 4             4                     Alderwood                  20.0
#
#             85           86           87                   88          1886
# 0    2 persons    3 persons    4 persons    5 or more persons      Employed  \
# 1     344110.0     174600.0     143250.0              56795.0     1361375.0
# 2       3570.0       2390.0       1875.0                605.0       12510.0
# 3       2970.0       1835.0       1325.0                520.0       10855.0
# 4       1605.0        900.0        755.0                220.0        6405.0
#
#              1887  Under $50,000  $50,000 - $100,000  $100,000 and over
# 0      Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over  \
# 1        122305.0       386930.0            342375.0           343520.0
# 2          1360.0         3310.0              3175.0             2505.0
# 3          1185.0         2975.0              2925.0             2030.0
# 4           415.0         1240.0              1480.0             1915.0
#
#    $200,000 and over  Post Secondary Degree  Bachelor level or above
# 0  $200,000 and over  Post Secondary Degree  Bachelor level or above  \
# 1            96600.0               468040.0                1424440.0
# 2              325.0                 4690.0                  10480.0
# 3              285.0                 4130.0                  10255.0
# 4              360.0                 2670.0                   4075.0
#
#                                        NO EDU
# 0    No certificate, diploma or degree-NO EDU  \
# 1                                    377340.0
# 2                                      6550.0
# 3                                      4035.0
# 4                                      2005.0
#
#                       Secondary school or equivalent
# 0    Secondary (high) school diploma or equivalen...  \
# 1                                           561090.0
# 2                                             7460.0
# 3                                             6090.0
# 4                                             2960.0
#
#                                   Trades certificate              HOOD_140
# 0        Trades certificate or diploma other than...  Neighbourhood Number
# 1                                            53060.0                     0
# 2                                              505.0                 129.0
# 3                                              375.0                 128.0
# 4                                              345.0                  20.0

# %%
dfn['HOOD_140'] = dfn['HOOD_140'].astype(str).str.replace('.0', '')

# %%
dfn.head()
# Out:
#    Unnamed: 0.1                    Unnamed: 0                     0
# 0             0                Characteristic  Neighbourhood Number  \
# 1             1               City of Toronto                   NaN
# 2             2               Agincourt North                 129.0
# 3             3  Agincourt South-Malvern West                 128.0
# 4             4                     Alderwood                  20.0
#
#             85           86           87                   88          1886
# 0    2 persons    3 persons    4 persons    5 or more persons      Employed  \
# 1     344110.0     174600.0     143250.0              56795.0     1361375.0
# 2       3570.0       2390.0       1875.0                605.0       12510.0
# 3       2970.0       1835.0       1325.0                520.0       10855.0
# 4       1605.0        900.0        755.0                220.0        6405.0
#
#              1887  Under $50,000  $50,000 - $100,000  $100,000 and over
# 0      Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over  \
# 1        122305.0       386930.0            342375.0           343520.0
# 2          1360.0         3310.0              3175.0             2505.0
# 3          1185.0         2975.0              2925.0             2030.0
# 4           415.0         1240.0              1480.0             1915.0
#
#    $200,000 and over  Post Secondary Degree  Bachelor level or above
# 0  $200,000 and over  Post Secondary Degree  Bachelor level or above  \
# 1            96600.0               468040.0                1424440.0
# 2              325.0                 4690.0                  10480.0
# 3              285.0                 4130.0                  10255.0
# 4              360.0                 2670.0                   4075.0
#
#                                        NO EDU
# 0    No certificate, diploma or degree-NO EDU  \
# 1                                    377340.0
# 2                                      6550.0
# 3                                      4035.0
# 4                                      2005.0
#
#                       Secondary school or equivalent
# 0    Secondary (high) school diploma or equivalen...  \
# 1                                           561090.0
# 2                                             7460.0
# 3                                             6090.0
# 4                                             2960.0
#
#                                   Trades certificate              HOOD_140
# 0        Trades certificate or diploma other than...  Neighbourhood Number
# 1                                            53060.0                     0
# 2                                              505.0                   129
# 3                                              375.0                   128
# 4                                              345.0                    20

# %%
dfn['HOOD_140'] = pd.to_numeric(dfn['HOOD_140'], errors='coerce').astype('Int64')

# %%
dfn.dtypes
# Out:
# Unnamed: 0.1                       int64
# Unnamed: 0                        object
# 0                                 object
# 85                                object
# 86                                object
# 87                                object
# 88                                object
# 1886                              object
# 1887                              object
# Under $50,000                     object
# $50,000 - $100,000                object
# $100,000 and over                 object
# $200,000 and over                 object
# Post Secondary Degree             object
# Bachelor level or above           object
# NO EDU                            object
# Secondary school or equivalent    object
# Trades certificate                object
# HOOD_140                           Int64
# dtype: object

# %%
df2.head()
# Out:
#    OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR OCC_MONTH
# 0         1   GO-2004397105  2004/05/15 04:00:00+00      2004       May  \
# 1         2   GO-2004600109  2004/07/26 04:00:00+00      2004      July
# 2         3   GO-2004311851  2004/05/14 04:00:00+00      2004       May
# 3         4   GO-2004736004  2004/12/19 05:00:00+00      2004  December
# 4         5   GO-2004303455  2004/04/12 04:00:00+00      2004     April
#
#     OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE  ... DEATH  INJURIES
# 0  Saturday      136       15         1          Night  ...     0         0  \
# 1    Monday      208       26        23        Evening  ...     0         0
# 2    Friday      135       14        16      Afternoon  ...     1         1
# 3    Sunday      354       19         0          Night  ...     1         0
# 4    Monday      103       12        22        Evening  ...     0         0
#
#    TOTAL_CASUALTIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0                 0       142            Woburn North      137  \
# 1                 0         1  West Humber-Clairville        1
# 2                 2        24             Black Creek       24
# 3                 1       168     Downtown Yonge East       75
# 4                 0       146            Malvern East      132
#
#             NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84  SEASON
# 0                Woburn (137) -79.234955  43.781528  Spring
# 1  West Humber-Clairville (1) -79.618218  43.733547  Summer
# 2            Black Creek (24) -79.518759  43.769157  Spring
# 3  Church-Yonge Corridor (75) -79.378870  43.660665    Fall
# 4               Malvern (132) -79.212435  43.812075  Spring
#
# [5 rows x 21 columns]

# %%
dfn.head(10)
# Out:
#    Unnamed: 0.1                    Unnamed: 0                     0
# 0             0                Characteristic  Neighbourhood Number  \
# 1             1               City of Toronto                   NaN
# 2             2               Agincourt North                 129.0
# 3             3  Agincourt South-Malvern West                 128.0
# 4             4                     Alderwood                  20.0
# 5             5                         Annex                  95.0
# 6             6             Banbury-Don Mills                  42.0
# 7             7                Bathurst Manor                  34.0
# 8             8           Bay Street Corridor                  76.0
# 9             9               Bayview Village                  52.0
#
#             85           86           87                   88          1886
# 0    2 persons    3 persons    4 persons    5 or more persons      Employed  \
# 1     344110.0     174600.0     143250.0              56795.0     1361375.0
# 2       3570.0       2390.0       1875.0                605.0       12510.0
# 3       2970.0       1835.0       1325.0                520.0       10855.0
# 4       1605.0        900.0        755.0                220.0        6405.0
# 5       4475.0       1195.0        805.0                215.0       17305.0
# 6       3925.0       1760.0       1500.0                435.0       13010.0
# 7       1945.0       1115.0        925.0                320.0        8000.0
# 8       3550.0        965.0        485.0                105.0       13455.0
# 9       3255.0       1570.0        980.0                255.0       10965.0
#
#              1887  Under $50,000  $50,000 - $100,000  $100,000 and over
# 0      Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over  \
# 1        122305.0       386930.0            342375.0           343520.0
# 2          1360.0         3310.0              3175.0             2505.0
# 3          1185.0         2975.0              2925.0             2030.0
# 4           415.0         1240.0              1480.0             1915.0
# 5          1250.0         4970.0              4015.0             5895.0
# 6          1010.0         3435.0              3855.0             4615.0
# 7           620.0         1930.0              1830.0             2025.0
# 8          1535.0         4985.0              3780.0             3600.0
# 9           910.0         2990.0              2935.0             3010.0
#
#    $200,000 and over  Post Secondary Degree  Bachelor level or above
# 0  $200,000 and over  Post Secondary Degree  Bachelor level or above  \
# 1            96600.0               468040.0                1424440.0
# 2              325.0                 4690.0                  10480.0
# 3              285.0                 4130.0                  10255.0
# 4              360.0                 2670.0                   4075.0
# 5             2670.0                 3580.0                  26685.0
# 6             1750.0                 4630.0                  18150.0
# 7              515.0                 2865.0                   8530.0
# 8             1105.0                 2240.0                  24140.0
# 9              855.0                 3750.0                  16360.0
#
#                                        NO EDU
# 0    No certificate, diploma or degree-NO EDU  \
# 1                                    377340.0
# 2                                      6550.0
# 3                                      4035.0
# 4                                      2005.0
# 5                                      1585.0
# 6                                      2295.0
# 7                                      1665.0
# 8                                       700.0
# 9                                      1310.0
#
#                       Secondary school or equivalent
# 0    Secondary (high) school diploma or equivalen...  \
# 1                                           561090.0
# 2                                             7460.0
# 3                                             6090.0
# 4                                             2960.0
# 5                                             4270.0
# 6                                             5150.0
# 7                                             3390.0
# 8                                             5740.0
# 9                                             3680.0
#
#                                   Trades certificate  HOOD_140
# 0        Trades certificate or diploma other than...      <NA>
# 1                                            53060.0         0
# 2                                              505.0       129
# 3                                              375.0       128
# 4                                              345.0        20
# 5                                              265.0        95
# 6                                              450.0        42
# 7                                              345.0        34
# 8                                              155.0        76
# 9                                              215.0        52

# %%
dfn.rename(columns={'Unnamed: 0': 'Neighbourhood Name', '0': 'Neighbourhood Number', '85': '2 persons', '86': '3 persons', '87': '4 persons', '88': '5 or more persons', '1886': 'Employed', '1887': 'Unemployed'}, inplace=True)

# %%
dfn.head()
# Out:
#    Unnamed: 0.1            Neighbourhood Name  Neighbourhood Number
# 0             0                Characteristic  Neighbourhood Number  \
# 1             1               City of Toronto                   NaN
# 2             2               Agincourt North                 129.0
# 3             3  Agincourt South-Malvern West                 128.0
# 4             4                     Alderwood                  20.0
#
#      2 persons    3 persons    4 persons    5 or more persons      Employed
# 0    2 persons    3 persons    4 persons    5 or more persons      Employed  \
# 1     344110.0     174600.0     143250.0              56795.0     1361375.0
# 2       3570.0       2390.0       1875.0                605.0       12510.0
# 3       2970.0       1835.0       1325.0                520.0       10855.0
# 4       1605.0        900.0        755.0                220.0        6405.0
#
#        Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over
# 0      Unemployed  Under $50,000  $50,000 - $100,000  $100,000 and over  \
# 1        122305.0       386930.0            342375.0           343520.0
# 2          1360.0         3310.0              3175.0             2505.0
# 3          1185.0         2975.0              2925.0             2030.0
# 4           415.0         1240.0              1480.0             1915.0
#
#    $200,000 and over  Post Secondary Degree  Bachelor level or above
# 0  $200,000 and over  Post Secondary Degree  Bachelor level or above  \
# 1            96600.0               468040.0                1424440.0
# 2              325.0                 4690.0                  10480.0
# 3              285.0                 4130.0                  10255.0
# 4              360.0                 2670.0                   4075.0
#
#                                        NO EDU
# 0    No certificate, diploma or degree-NO EDU  \
# 1                                    377340.0
# 2                                      6550.0
# 3                                      4035.0
# 4                                      2005.0
#
#                       Secondary school or equivalent
# 0    Secondary (high) school diploma or equivalen...  \
# 1                                           561090.0
# 2                                             7460.0
# 3                                             6090.0
# 4                                             2960.0
#
#                                   Trades certificate  HOOD_140
# 0        Trades certificate or diploma other than...      <NA>
# 1                                            53060.0         0
# 2                                              505.0       129
# 3                                              375.0       128
# 4                                              345.0        20

# %%
merged_df = df2.merge(dfn, on='HOOD_140', how='left')

# %%
merged_df.head(10)
# Out:
#    OBJECTID EVENT_UNIQUE_ID                OCC_DATE  OCC_YEAR  OCC_MONTH
# 0         1   GO-2004397105  2004/05/15 04:00:00+00      2004        May  \
# 1         2   GO-2004600109  2004/07/26 04:00:00+00      2004       July
# 2         3   GO-2004311851  2004/05/14 04:00:00+00      2004        May
# 3         4   GO-2004736004  2004/12/19 05:00:00+00      2004   December
# 4         5   GO-2004303455  2004/04/12 04:00:00+00      2004      April
# 5         6   GO-2004213938  2004/03/14 05:00:00+00      2004      March
# 6         7   GO-2004149554  2004/01/19 05:00:00+00      2004    January
# 7         8   GO-2004646393  2004/09/08 04:00:00+00      2004  September
# 8         9   GO-2004764704  2004/04/14 04:00:00+00      2004      April
# 9        11   GO-2004619258  2004/10/27 04:00:00+00      2004    October
#
#      OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE  ... Unemployed
# 0   Saturday      136       15         1          Night  ...     2665.0  \
# 1     Monday      208       26        23        Evening  ...     1705.0
# 2     Friday      135       14        16      Afternoon  ...     1180.0
# 3     Sunday      354       19         0          Night  ...     1865.0
# 4     Monday      103       12        22        Evening  ...     2335.0
# 5     Sunday       74       14         0          Night  ...     1685.0
# 6     Monday       19       19        23        Evening  ...     2010.0
# 7  Wednesday      252        8        14      Afternoon  ...     1785.0
# 8  Wednesday      105       14        23        Evening  ...     1125.0
# 9  Wednesday      301       27        20        Evening  ...     1685.0
#
#    Under $50,000  $50,000 - $100,000  $100,000 and over  $200,000 and over
# 0         7505.0              6305.0             3980.0              430.0  \
# 1         3250.0              3870.0             3085.0              310.0
# 2         3670.0              2455.0              900.0               40.0
# 3         7270.0              5940.0             4840.0             1130.0
# 4         4830.0              5260.0             3280.0              225.0
# 5         4695.0              4545.0             3795.0              890.0
# 6         2785.0              4635.0             6060.0             1075.0
# 7         4395.0              3810.0             1705.0              110.0
# 8         5900.0              3170.0             1505.0              240.0
# 9         4695.0              4545.0             3795.0              890.0
#
#   Post Secondary Degree  Bachelor level or above  NO EDU
# 0                9485.0                  19140.0  8850.0  \
# 1                6415.0                  10825.0  5905.0
# 2                3245.0                   2890.0  6420.0
# 3                4935.0                  28365.0  1220.0
# 4                8560.0                  13080.0  7345.0
# 5                6955.0                  16245.0  4140.0
# 6                9585.0                  16600.0  6580.0
# 7                4945.0                   7735.0  7895.0
# 8                4570.0                  10430.0  3050.0
# 9                6955.0                  16245.0  4140.0
#
#    Secondary school or equivalent  Trades certificate
# 0                         13170.0              1025.0
# 1                          8510.0               835.0
# 2                          5195.0               535.0
# 3                          5510.0               480.0
# 4                         11575.0              1155.0
# 5                          7660.0               700.0
# 6                         11740.0              1020.0
# 7                          7785.0               680.0
# 8                          4520.0               535.0
# 9                          7660.0               700.0
#
# [10 rows x 39 columns]

# %%
merged_df.describe(include = 'all')
# Out:
#            OBJECTID EVENT_UNIQUE_ID                OCC_DATE     OCC_YEAR
# count   5643.000000            5643                    5643  5643.000000  \
# unique          NaN            5643                    3554          NaN
# top             NaN   GO-2004397105  2019/08/05 04:00:00+00          NaN
# freq            NaN               1                       9          NaN
# mean    2874.332624             NaN                     NaN  2014.532164
# std     1643.956540             NaN                     NaN     5.448039
# min        1.000000             NaN                     NaN  2004.000000
# 25%     1453.500000             NaN                     NaN  2010.000000
# 50%     2886.000000             NaN                     NaN  2016.000000
# 75%     4296.500000             NaN                     NaN  2019.000000
# max     5707.000000             NaN                     NaN  2022.000000
#
#        OCC_MONTH OCC_DOW      OCC_DOY      OCC_DAY     OCC_HOUR
# count       5643    5643  5643.000000  5643.000000  5643.000000  \
# unique        12       7          NaN          NaN          NaN
# top       August  Sunday          NaN          NaN          NaN
# freq         599     990          NaN          NaN          NaN
# mean         NaN     NaN   187.136807    15.905369    12.079745
# std          NaN     NaN   100.372513     8.824548     8.685902
# min          NaN     NaN     1.000000     1.000000     0.000000
# 25%          NaN     NaN   106.000000     8.000000     3.000000
# 50%          NaN     NaN   192.000000    16.000000    15.000000
# 75%          NaN     NaN   268.000000    23.000000    20.000000
# max          NaN     NaN   366.000000    31.000000    23.000000
#
#        OCC_TIME_RANGE  ... Unemployed  Under $50,000  $50,000 - $100,000
# count            5643  ...       5643           5643                5643  \
# unique              4  ...        111            128                 126
# top           Evening  ...     1550.0         3670.0              3295.0
# freq             2275  ...        304            313                 304
# mean              NaN  ...        NaN            NaN                 NaN
# std               NaN  ...        NaN            NaN                 NaN
# min               NaN  ...        NaN            NaN                 NaN
# 25%               NaN  ...        NaN            NaN                 NaN
# 50%               NaN  ...        NaN            NaN                 NaN
# 75%               NaN  ...        NaN            NaN                 NaN
# max               NaN  ...        NaN            NaN                 NaN
#
#         $100,000 and over  $200,000 and over Post Secondary Degree
# count                5643               5643                  5643  \
# unique                128                112                   131
# top                1835.0              140.0                4750.0
# freq                  304                304                   304
# mean                  NaN                NaN                   NaN
# std                   NaN                NaN                   NaN
# min                   NaN                NaN                   NaN
# 25%                   NaN                NaN                   NaN
# 50%                   NaN                NaN                   NaN
# 75%                   NaN                NaN                   NaN
# max                   NaN                NaN                   NaN
#
#         Bachelor level or above  NO EDU  Secondary school or equivalent
# count                      5643    5643                            5643  \
# unique                      136     130                             131
# top                      3880.0  9560.0                          7190.0
# freq                        304     304                             304
# mean                        NaN     NaN                             NaN
# std                         NaN     NaN                             NaN
# min                         NaN     NaN                             NaN
# 25%                         NaN     NaN                             NaN
# 50%                         NaN     NaN                             NaN
# 75%                         NaN     NaN                             NaN
# max                         NaN     NaN                             NaN
#
#         Trades certificate
# count                 5643
# unique                  88
# top                  790.0
# freq                   304
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [11 rows x 39 columns]

# %%
df = merged_df

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
import seaborn as sns
import scipy.stats as stats
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler, quantile_transform
from sklearn.impute import SimpleImputer

from sklearn.metrics import mean_absolute_error, r2_score
import statsmodels.api as sm

# %%
df.dtypes
# Out:
# OBJECTID                            int64
# EVENT_UNIQUE_ID                    object
# OCC_DATE                           object
# OCC_YEAR                            int64
# OCC_MONTH                          object
# OCC_DOW                            object
# OCC_DOY                             int64
# OCC_DAY                             int64
# OCC_HOUR                            int64
# OCC_TIME_RANGE                     object
# DIVISION                           object
# DEATH                               int64
# INJURIES                            int64
# TOTAL_CASUALTIES                    int64
# HOOD_158                            int64
# NEIGHBOURHOOD_158                  object
# HOOD_140                            int64
# NEIGHBOURHOOD_140                  object
# LONG_WGS84                        float64
# LAT_WGS84                         float64
# SEASON                             object
# Unnamed: 0.1                        int64
# Neighbourhood Name                 object
# Neighbourhood Number               object
# 2 persons                          object
# 3 persons                          object
# 4 persons                          object
# 5 or more persons                  object
# Employed                           object
# Unemployed                         object
# Under $50,000                      object
# $50,000 - $100,000                 object
# $100,000 and over                  object
# $200,000 and over                  object
# Post Secondary Degree              object
# Bachelor level or above            object
# NO EDU                             object
# Secondary school or equivalent     object
# Trades certificate                 object
# dtype: object

# %%
columns_to_convert = ['Neighbourhood Number', '2 persons', '3 persons', '4 persons', '5 or more persons', 'Employed', 'Unemployed', 'Under $50,000', '$50,000 - $100,000', '$100,000 and over', '$200,000 and over', 'Post Secondary Degree', 'Bachelor level or above', 'NO EDU', 'Secondary school or equivalent', 'Trades certificate']
df[columns_to_convert] = df[columns_to_convert].astype(float)
df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
df['DIVISION'].str.contains('^D').all()
# Out:
# True

# %%
df['SEASON']
# Out:
# 0       Spring
# 1       Summer
# 2       Spring
# 3         Fall
# 4       Spring
#          ...
# 5638    Spring
# 5639    Summer
# 5640    Winter
# 5641    Summer
# 5642    Spring
# Name: SEASON, Length: 5643, dtype: object

# %%
df['SEASON_NUM'] = df['SEASON'].map({'Winter':1, 'Spring': 2, 'Summer':3, 'Fall':4})

# %%
df['OCC_YEAR'] = df['OCC_YEAR'].astype(int)
df['OBJECTID'] = df['OBJECTID'].astype(int)
df['DIVISION'] = df['DIVISION'].str.replace('D', '').astype(int)

# %%
df['OCC_DATE'] = pd.to_datetime(df['OCC_DATE'])

# %%
month_mapping = {'January': 1,'February': 2,'March': 3,'April': 4,'May': 5,'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
df['OCC_MONTH'] = df['OCC_MONTH'].map(month_mapping)

# %%
dow_mapping = {'Monday':1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
df['OCC_DOW'] = df['OCC_DOW'].map(dow_mapping)

# %%
df = df.drop(['EVENT_UNIQUE_ID'], axis=1)

# %%
df.head()
# Out:
#    OBJECTID                  OCC_DATE  OCC_YEAR  OCC_MONTH  OCC_DOW  OCC_DOY
# 0         1 2004-05-15 04:00:00+00:00      2004          5        6      136  \
# 1         2 2004-07-26 04:00:00+00:00      2004          7        1      208
# 2         3 2004-05-14 04:00:00+00:00      2004          5        5      135
# 3         4 2004-12-19 05:00:00+00:00      2004         12        7      354
# 4         5 2004-04-12 04:00:00+00:00      2004          4        1      103
#
#    OCC_DAY  OCC_HOUR OCC_TIME_RANGE  DIVISION  ...  Under $50,000
# 0       15         1          Night        41  ...           7505  \
# 1       26        23        Evening        23  ...           3250
# 2       14        16      Afternoon        31  ...           3670
# 3       19         0          Night        51  ...           7270
# 4       12        22        Evening        42  ...           4830
#
#    $50,000 - $100,000  $100,000 and over  $200,000 and over
# 0                6305               3980                430  \
# 1                3870               3085                310
# 2                2455                900                 40
# 3                5940               4840               1130
# 4                5260               3280                225
#
#   Post Secondary Degree  Bachelor level or above NO EDU
# 0                  9485                    19140   8850  \
# 1                  6415                    10825   5905
# 2                  3245                     2890   6420
# 3                  4935                    28365   1220
# 4                  8560                    13080   7345
#
#    Secondary school or equivalent  Trades certificate SEASON_NUM
# 0                           13170                1025          2
# 1                            8510                 835          3
# 2                            5195                 535          2
# 3                            5510                 480          4
# 4                           11575                1155          2
#
# [5 rows x 39 columns]

# %%
df['OCC_TIME_RANGE'].unique()
# Out:
# array(['Night', 'Evening', 'Afternoon', 'Morning'], dtype=object)

# %%
df['OCC_TIME_RANGE'] = df['OCC_TIME_RANGE'].map({'Morning':1, 'Afternoon':2, 'Evening':3, 'Night':4})

# %%
df['Unnamed: 0.1'].describe()
# Out:
# count    5643.000000
# mean       74.877016
# std        39.952397
# min         2.000000
# 25%        41.000000
# 50%        75.000000
# 75%       110.000000
# max       141.000000
# Name: Unnamed: 0.1, dtype: float64

# %%
df.describe(include='all')
# Out:
#            OBJECTID                             OCC_DATE     OCC_YEAR
# count   5643.000000                                 5643  5643.000000  \
# unique          NaN                                  NaN          NaN
# top             NaN                                  NaN          NaN
# freq            NaN                                  NaN          NaN
# mean    2874.332624  2015-01-16 13:38:54.928229632+00:00  2014.532164
# min        1.000000            2004-01-01 05:00:00+00:00  2004.000000
# 25%     1453.500000            2010-06-19 04:00:00+00:00  2010.000000
# 50%     2886.000000            2016-05-24 04:00:00+00:00  2016.000000
# 75%     4296.500000            2019-09-22 04:00:00+00:00  2019.000000
# max     5707.000000            2022-12-31 05:00:00+00:00  2022.000000
# std     1643.956540                                  NaN     5.448039
#
#           OCC_MONTH      OCC_DOW      OCC_DOY      OCC_DAY     OCC_HOUR
# count   5643.000000  5643.000000  5643.000000  5643.000000  5643.000000  \
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       6.649832     4.213362   187.136807    15.905369    12.079745
# min        1.000000     1.000000     1.000000     1.000000     0.000000
# 25%        4.000000     2.000000   106.000000     8.000000     3.000000
# 50%        7.000000     4.000000   192.000000    16.000000    15.000000
# 75%        9.000000     6.000000   268.000000    23.000000    20.000000
# max       12.000000     7.000000   366.000000    31.000000    23.000000
# std        3.278140     2.055466   100.372513     8.824548     8.685902
#
#         OCC_TIME_RANGE     DIVISION  ...  Under $50,000  $50,000 - $100,000
# count      5643.000000  5643.000000  ...    5643.000000         5643.000000  \
# unique             NaN          NaN  ...            NaN                 NaN
# top                NaN          NaN  ...            NaN                 NaN
# freq               NaN          NaN  ...            NaN                 NaN
# mean          3.077795    32.382775  ...    3742.970937         3246.369839
# min           1.000000    11.000000  ...     325.000000          470.000000
# 25%           3.000000    23.000000  ...    2395.000000         1895.000000
# 50%           3.000000    31.000000  ...    3670.000000         2755.000000
# 75%           4.000000    42.000000  ...    4725.000000         3810.000000
# max           4.000000    55.000000  ...   10340.000000        13520.000000
# std           0.882984    13.483347  ...    1852.609930         2228.751463
#
#         $100,000 and over  $200,000 and over Post Secondary Degree
# count         5643.000000        5643.000000           5643.000000  \
# unique                NaN                NaN                   NaN
# top                   NaN                NaN                   NaN
# freq                  NaN                NaN                   NaN
# mean          2608.631047         511.705653           4373.172958
# min            430.000000          40.000000            760.000000
# 25%           1340.000000         140.000000           2600.000000
# 50%           1890.000000         295.000000           3865.000000
# 75%           3015.000000         550.000000           5035.000000
# max          14995.000000        3850.000000           9585.000000
# std           2485.080831         718.649491           2222.885675
#
#         Bachelor level or above       NO EDU  Secondary school or equivalent
# count               5643.000000  5643.000000                     5643.000000  \
# unique                      NaN          NaN                             NaN
# top                         NaN          NaN                             NaN
# freq                        NaN          NaN                             NaN
# mean               10896.306043  4292.034379                     5561.947546
# min                 1130.000000   460.000000                     1190.000000
# 25%                 4310.000000  2270.000000                     3385.000000
# 50%                 8195.000000  3635.000000                     5195.000000
# 75%                11730.000000  6320.000000                     7190.000000
# max                71375.000000  9560.000000                    13170.000000
# std                12023.278284  2500.363166                     2751.885561
#
#         Trades certificate   SEASON_NUM
# count          5643.000000  5643.000000
# unique                 NaN          NaN
# top                    NaN          NaN
# freq                   NaN          NaN
# mean            543.288145     2.543860
# min              80.000000     1.000000
# 25%             315.000000     2.000000
# 50%             535.000000     3.000000
# 75%             755.000000     3.000000
# max            1155.000000     4.000000
# std             260.672671     1.062217
#
# [11 rows x 39 columns]

# %%
df.dtypes
# Out:
# OBJECTID                                        int64
# OCC_DATE                          datetime64[ns, UTC]
# OCC_YEAR                                        int64
# OCC_MONTH                                       int64
# OCC_DOW                                         int64
# OCC_DOY                                         int64
# OCC_DAY                                         int64
# OCC_HOUR                                        int64
# OCC_TIME_RANGE                                  int64
# DIVISION                                        int64
# DEATH                                           int64
# INJURIES                                        int64
# TOTAL_CASUALTIES                                int64
# HOOD_158                                        int64
# NEIGHBOURHOOD_158                              object
# HOOD_140                                        int64
# NEIGHBOURHOOD_140                              object
# LONG_WGS84                                    float64
# LAT_WGS84                                     float64
# SEASON                                         object
# Unnamed: 0.1                                    int64
# Neighbourhood Name                             object
# Neighbourhood Number                            int64
# 2 persons                                       int64
# 3 persons                                       int64
# 4 persons                                       int64
# 5 or more persons                               int64
# Employed                                        int64
# Unemployed                                      int64
# Under $50,000                                   int64
# $50,000 - $100,000                              int64
# $100,000 and over                               int64
# $200,000 and over                               int64
# Post Secondary Degree                           int64
# Bachelor level or above                         int64
# NO EDU                                          int64
# Secondary school or equivalent                  int64
# Trades certificate                              int64
# SEASON_NUM                                      int64
# dtype: object

# %%
df.head()
# Out:
#    OBJECTID                  OCC_DATE  OCC_YEAR  OCC_MONTH  OCC_DOW  OCC_DOY
# 0         1 2004-05-15 04:00:00+00:00      2004          5        6      136  \
# 1         2 2004-07-26 04:00:00+00:00      2004          7        1      208
# 2         3 2004-05-14 04:00:00+00:00      2004          5        5      135
# 3         4 2004-12-19 05:00:00+00:00      2004         12        7      354
# 4         5 2004-04-12 04:00:00+00:00      2004          4        1      103
#
#    OCC_DAY  OCC_HOUR  OCC_TIME_RANGE  DIVISION  ...  Under $50,000
# 0       15         1               4        41  ...           7505  \
# 1       26        23               3        23  ...           3250
# 2       14        16               2        31  ...           3670
# 3       19         0               4        51  ...           7270
# 4       12        22               3        42  ...           4830
#
#    $50,000 - $100,000  $100,000 and over  $200,000 and over
# 0                6305               3980                430  \
# 1                3870               3085                310
# 2                2455                900                 40
# 3                5940               4840               1130
# 4                5260               3280                225
#
#   Post Secondary Degree  Bachelor level or above NO EDU
# 0                  9485                    19140   8850  \
# 1                  6415                    10825   5905
# 2                  3245                     2890   6420
# 3                  4935                    28365   1220
# 4                  8560                    13080   7345
#
#    Secondary school or equivalent  Trades certificate SEASON_NUM
# 0                           13170                1025          2
# 1                            8510                 835          3
# 2                            5195                 535          2
# 3                            5510                 480          4
# 4                           11575                1155          2
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643 entries, 0 to 5642
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTID                        5643 non-null   int64
#  1   OCC_DATE                        5643 non-null   datetime64[ns, UTC]
#  2   OCC_YEAR                        5643 non-null   int64
#  3   OCC_MONTH                       5643 non-null   int64
#  4   OCC_DOW                         5643 non-null   int64
#  5   OCC_DOY                         5643 non-null   int64
#  6   OCC_DAY                         5643 non-null   int64
#  7   OCC_HOUR                        5643 non-null   int64
#  8   OCC_TIME_RANGE                  5643 non-null   int64
#  9   DIVISION                        5643 non-null   int64
#  10  DEATH                           5643 non-null   int64
#  11  INJURIES                        5643 non-null   int64
#  12  TOTAL_CASUALTIES                5643 non-null   int64
#  13  HOOD_158                        5643 non-null   int64
#  14  NEIGHBOURHOOD_158               5643 non-null   object
#  15  HOOD_140                        5643 non-null   int64
#  16  NEIGHBOURHOOD_140               5643 non-null   object
#  17  LONG_WGS84                      5643 non-null   float64
#  18  LAT_WGS84                       5643 non-null   float64
#  19  SEASON                          5643 non-null   object
#  20  Unnamed: 0.1                    5643 non-null   int64
#  21  Neighbourhood Name              5643 non-null   object
#  22  Neighbourhood Number            5643 non-null   int64
#  23  2 persons                       5643 non-null   int64
#  24  3 persons                       5643 non-null   int64
#  25  4 persons                       5643 non-null   int64
#  26  5 or more persons               5643 non-null   int64
#  27  Employed                        5643 non-null   int64
#  28  Unemployed                      5643 non-null   int64
#  29  Under $50,000                   5643 non-null   int64
#  30  $50,000 - $100,000              5643 non-null   int64
#  31  $100,000 and over               5643 non-null   int64
#  32  $200,000 and over               5643 non-null   int64
#  33  Post Secondary Degree           5643 non-null   int64
#  34  Bachelor level or above         5643 non-null   int64
#  35  NO EDU                          5643 non-null   int64
#  36  Secondary school or equivalent  5643 non-null   int64
#  37  Trades certificate              5643 non-null   int64
#  38  SEASON_NUM                      5643 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(2), int64(32), object(4)
# memory usage: 1.7+ MB

# %%
new_column_names = {
    'LONG_WGS84': 'LONG',
    'LAT_WGS84': 'LAT',
    'Neighbourhood Name': 'NEIGHBOURHOOD_NAME',
    'Neighbourhood Number':'NEIGHBOURHOOD_NUM', 
    '2 persons': '2_PERSONS',
    '3 persons': '3_PERSONS',
    '4 persons': '4_PERSONS',
    '5 or more persons' : '5_OR_MORE_PERSONS',
    'Under $50,000' : 'UNDER_50000',
    '$50,000 - $100,000': '50000-100000',
    '$100,000 and over': '100000+',
    '$200,000 and over': '200000+',
    'Post Secondary Degree': 'POST_SECONDARY_DEGREE',
    'Bachelor level or above': 'BACHELOR_OR_ABOVE',
    'NO EDU': 'NO_EDU',
    'Secondary school or equivalent': 'SECONDARY_OR_EQUIV',
    'Trades certificate' : 'TRADES_CERT'}
df = df.rename(columns=new_column_names)

# %%
columns = df.columns.drop(['OBJECTID', 'OCC_DATE', 'NEIGHBOURHOOD_140', 'SEASON', 'NEIGHBOURHOOD_NAME', 'NEIGHBOURHOOD_158'])
num_rows = (len(columns) - 1) // 3 + 1
num_cols = 3

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5*num_rows))
fig.tight_layout()

for i, column in enumerate(columns):
    ax = axes[i // num_cols, i % num_cols]
    sns.boxplot(data=df, y=column, ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel(column)
plt.show()

# %%
num_plots = len(columns)
num_cols = 3
num_rows = (num_plots - 1) // num_cols + 1

fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 3 * num_rows))
fig.tight_layout()

for i, column in enumerate(columns):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]
    sns.histplot(data=df, x=column, ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel('Count')

plt.show()

# %%
df_hood_grouped = df.copy()

# %%
df_hood_grouped = df_hood_grouped.drop(['OCC_DATE', 'NEIGHBOURHOOD_140', 'SEASON', 'NEIGHBOURHOOD_NAME', 'NEIGHBOURHOOD_158'], axis=1)

# %%
df_hood_grouped['HOOD_140'].unique()
# Out:
# array([137,   1,  24,  75, 132,  45, 131,   2,  85, 113, 124, 111,  72,
#        126, 136,   5, 118,  28, 117,  58,  76,  73, 120,  70,  27,  77,
#         84,  78,  43,  74, 134,  23,  50,  93, 107,  26,  83, 108,  25,
#         54,  16,  29,  30,  18,  14, 138,  17,  32,   8,  59, 130,   4,
#        128, 121,  89,  44, 110, 135,  40,  48, 104,  87,  13,  88,  31,
#        127, 139,  92,  91,  97,  61, 123,  57,  53,  90,  47, 109, 116,
#         21,  65, 122,  11,  71,  82,   7,  38,  66,   6,  81,  62,  22,
#         42,  12, 119,  98,  51, 125,  95,  69, 115,  36,   3,  55,  68,
#         80,  86,  19, 112,  20,  79,  64, 129, 106,  99,  60,  41,  49,
#         94,   9,  34,  52,  46,  35, 114,  33,  67,  15,  39,  96,  56,
#         63, 140, 100, 133, 105,  37,  10, 101, 102])

# %%
grouped_df_sum = df_hood_grouped.groupby('HOOD_140').sum()
grouped_df_mean = df_hood_grouped.groupby('HOOD_140').mean()

# %%
df_hood_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643 entries, 0 to 5642
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               5643 non-null   int64
#  1   OCC_YEAR               5643 non-null   int64
#  2   OCC_MONTH              5643 non-null   int64
#  3   OCC_DOW                5643 non-null   int64
#  4   OCC_DOY                5643 non-null   int64
#  5   OCC_DAY                5643 non-null   int64
#  6   OCC_HOUR               5643 non-null   int64
#  7   OCC_TIME_RANGE         5643 non-null   int64
#  8   DIVISION               5643 non-null   int64
#  9   DEATH                  5643 non-null   int64
#  10  INJURIES               5643 non-null   int64
#  11  TOTAL_CASUALTIES       5643 non-null   int64
#  12  HOOD_158               5643 non-null   int64
#  13  HOOD_140               5643 non-null   int64
#  14  LONG                   5643 non-null   float64
#  15  LAT                    5643 non-null   float64
#  16  Unnamed: 0.1           5643 non-null   int64
#  17  NEIGHBOURHOOD_NUM      5643 non-null   int64
#  18  2_PERSONS              5643 non-null   int64
#  19  3_PERSONS              5643 non-null   int64
#  20  4_PERSONS              5643 non-null   int64
#  21  5_OR_MORE_PERSONS      5643 non-null   int64
#  22  Employed               5643 non-null   int64
#  23  Unemployed             5643 non-null   int64
#  24  UNDER_50000            5643 non-null   int64
#  25  50000-100000           5643 non-null   int64
#  26  100000+                5643 non-null   int64
#  27  200000+                5643 non-null   int64
#  28  POST_SECONDARY_DEGREE  5643 non-null   int64
#  29  BACHELOR_OR_ABOVE      5643 non-null   int64
#  30  NO_EDU                 5643 non-null   int64
#  31  SECONDARY_OR_EQUIV     5643 non-null   int64
#  32  TRADES_CERT            5643 non-null   int64
#  33  SEASON_NUM             5643 non-null   int64
# dtypes: float64(2), int64(32)
# memory usage: 1.5 MB

# %%
df_hood_grouped['CALLS'] = 1

# %%
df_hood_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643 entries, 0 to 5642
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               5643 non-null   int64
#  1   OCC_YEAR               5643 non-null   int64
#  2   OCC_MONTH              5643 non-null   int64
#  3   OCC_DOW                5643 non-null   int64
#  4   OCC_DOY                5643 non-null   int64
#  5   OCC_DAY                5643 non-null   int64
#  6   OCC_HOUR               5643 non-null   int64
#  7   OCC_TIME_RANGE         5643 non-null   int64
#  8   DIVISION               5643 non-null   int64
#  9   DEATH                  5643 non-null   int64
#  10  INJURIES               5643 non-null   int64
#  11  TOTAL_CASUALTIES       5643 non-null   int64
#  12  HOOD_158               5643 non-null   int64
#  13  HOOD_140               5643 non-null   int64
#  14  LONG                   5643 non-null   float64
#  15  LAT                    5643 non-null   float64
#  16  Unnamed: 0.1           5643 non-null   int64
#  17  NEIGHBOURHOOD_NUM      5643 non-null   int64
#  18  2_PERSONS              5643 non-null   int64
#  19  3_PERSONS              5643 non-null   int64
#  20  4_PERSONS              5643 non-null   int64
#  21  5_OR_MORE_PERSONS      5643 non-null   int64
#  22  Employed               5643 non-null   int64
#  23  Unemployed             5643 non-null   int64
#  24  UNDER_50000            5643 non-null   int64
#  25  50000-100000           5643 non-null   int64
#  26  100000+                5643 non-null   int64
#  27  200000+                5643 non-null   int64
#  28  POST_SECONDARY_DEGREE  5643 non-null   int64
#  29  BACHELOR_OR_ABOVE      5643 non-null   int64
#  30  NO_EDU                 5643 non-null   int64
#  31  SECONDARY_OR_EQUIV     5643 non-null   int64
#  32  TRADES_CERT            5643 non-null   int64
#  33  SEASON_NUM             5643 non-null   int64
#  34  CALLS                  5643 non-null   int64
# dtypes: float64(2), int64(33)
# memory usage: 1.5 MB

# %%
df_hood_grouped = df_hood_grouped.groupby('HOOD_140').agg({'OCC_YEAR': lambda x: x.mode()[0], 'OCC_MONTH': lambda x: x.mode()[0], 
                                                           'OCC_DOW': lambda x: x.mode()[0], 'OCC_DOY': lambda x: x.mode()[0],'OCC_DAY': lambda x: x.mode()[0], 'OCC_HOUR': lambda x: x.mode()[0], 
                                                           'DIVISION': lambda x: x.mode()[0], 'CALLS': 'sum','DEATH' : 'sum', 'INJURIES': 'sum','TOTAL_CASUALTIES': 'sum', 'LONG': 'mean',
                                                           'LAT': 'mean', '2_PERSONS': 'mean', '3_PERSONS': 'mean', '4_PERSONS': 'mean',
                                                             '5_OR_MORE_PERSONS': 'mean', 'Employed': 'mean', 'Unemployed': 'mean', 'UNDER_50000': 'mean', '50000-100000': 'mean', '100000+': 'mean',
                                                             '200000+': 'mean', 'POST_SECONDARY_DEGREE': 'mean', 'BACHELOR_OR_ABOVE' : 'mean', 'NO_EDU': 'mean', 'SECONDARY_OR_EQUIV': 'mean',
                                                             'TRADES_CERT': 'mean', 'SEASON_NUM': lambda x: x.mode()[0]})

# %%
df_hood_grouped.head()
# Out:
#           OCC_YEAR  OCC_MONTH  OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR  DIVISION
# HOOD_140
# 1             2018          7        7       99        1         0        23  \
# 2             2011          5        7      271       19        22        23
# 3             2022         10        4        5        6         0        23
# 4             2019          1        2      310       17         0        23
# 5             2019          4        7       40        2        23        23
#
#           CALLS  DEATH  INJURIES  ...  UNDER_50000  50000-100000  100000+
# HOOD_140                          ...
# 1           132     11        74  ...       3250.0        3870.0   3085.0  \
# 2           192     28        88  ...       4395.0        3810.0   1705.0
# 3            21      3         3  ...       1230.0        1140.0    940.0
# 4            28      3         9  ...       1450.0        1295.0   1040.0
# 5            68      8        33  ...       1325.0        1180.0    730.0
#
#           200000+  POST_SECONDARY_DEGREE  BACHELOR_OR_ABOVE  NO_EDU
# HOOD_140
# 1           310.0                 6415.0            10825.0  5905.0  \
# 2           110.0                 4945.0             7735.0  7895.0
# 3           120.0                 2030.0             2960.0  2075.0
# 4            95.0                 2140.0             2935.0  1960.0
# 5            60.0                 1770.0             2030.0  1870.0
#
#           SECONDARY_OR_EQUIV  TRADES_CERT  SEASON_NUM
# HOOD_140
# 1                     8510.0        835.0           3
# 2                     7785.0        680.0           2
# 3                     2340.0        265.0           4
# 4                     2675.0        330.0           1
# 5                     2620.0        255.0           2
#
# [5 rows x 29 columns]

# %%
grouped_columns = df_hood_grouped.columns

# %%
num_plots = len(df_hood_grouped.columns)
num_cols = 3
num_rows = (num_plots - 1) // num_cols + 1

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))
fig.tight_layout()

# Iterate over the columns
for i, column in enumerate(df_hood_grouped.columns):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Create line plot
    ax.plot(df_hood_grouped.index, df_hood_grouped[column], marker='o', linestyle='-')
    ax.set_xlabel(column)

plt.show()

# %%
correlations = [(column, df[column].corr(df['TOTAL_CASUALTIES'])) for column in columns]
correlations_sorted = sorted(correlations, key=lambda x: abs(x[1]), reverse=True)

for column, corr_coeff in correlations_sorted:
    print(f"Correlation between {column} and total casualties: {corr_coeff:.2f}")
# Out:
# Correlation between TOTAL_CASUALTIES and total casualties: 1.00
# Correlation between INJURIES and total casualties: 0.91
# Correlation between DEATH and total casualties: 0.38
# Correlation between OCC_YEAR and total casualties: -0.14
# Correlation between LAT and total casualties: -0.06
# Correlation between 5_OR_MORE_PERSONS and total casualties: -0.05
# Correlation between 4_PERSONS and total casualties: -0.04
# Correlation between HOOD_158 and total casualties: 0.04
# Correlation between BACHELOR_OR_ABOVE and total casualties: 0.03
# Correlation between 200000+ and total casualties: 0.03
# Correlation between NO_EDU and total casualties: -0.03
# Correlation between OCC_TIME_RANGE and total casualties: 0.03
# Correlation between 100000+ and total casualties: 0.03
# Correlation between TRADES_CERT and total casualties: -0.03
# Correlation between 3_PERSONS and total casualties: -0.02
# Correlation between OCC_DOW and total casualties: 0.02
# Correlation between UNDER_50000 and total casualties: 0.02
# Correlation between Employed and total casualties: 0.02
# Correlation between SEASON_NUM and total casualties: 0.02
# Correlation between HOOD_140 and total casualties: 0.02
# Correlation between NEIGHBOURHOOD_NUM and total casualties: 0.02
# Correlation between 50000-100000 and total casualties: 0.02
# Correlation between 2_PERSONS and total casualties: 0.02
# Correlation between LONG and total casualties: 0.02
# Correlation between SECONDARY_OR_EQUIV and total casualties: -0.01
# Correlation between DIVISION and total casualties: 0.01
# Correlation between OCC_DOY and total casualties: 0.01
# Correlation between OCC_MONTH and total casualties: 0.01
# Correlation between OCC_HOUR and total casualties: -0.01
# Correlation between POST_SECONDARY_DEGREE and total casualties: -0.01
# Correlation between OCC_DAY and total casualties: 0.00
# Correlation between Unnamed: 0.1 and total casualties: 0.00
# Correlation between Unemployed and total casualties: 0.00

# %%
correlations = [(column, df_hood_grouped[column].corr(df_hood_grouped['TOTAL_CASUALTIES'])) for column in grouped_columns]
correlations_sorted = sorted(correlations, key=lambda x: abs(x[1]), reverse=True)

for column, corr_coeff in correlations_sorted:
    print(f"Correlation between {column} and total casualties: {corr_coeff:.2f}")
# Out:
# Correlation between TOTAL_CASUALTIES and total casualties: 1.00
# Correlation between INJURIES and total casualties: 0.99
# Correlation between CALLS and total casualties: 0.97
# Correlation between DEATH and total casualties: 0.90
# Correlation between NO_EDU and total casualties: 0.69
# Correlation between TRADES_CERT and total casualties: 0.61
# Correlation between Unemployed and total casualties: 0.58
# Correlation between SECONDARY_OR_EQUIV and total casualties: 0.57
# Correlation between UNDER_50000 and total casualties: 0.56
# Correlation between 5_OR_MORE_PERSONS and total casualties: 0.53
# Correlation between POST_SECONDARY_DEGREE and total casualties: 0.48
# Correlation between 50000-100000 and total casualties: 0.46
# Correlation between 3_PERSONS and total casualties: 0.43
# Correlation between Employed and total casualties: 0.41
# Correlation between 2_PERSONS and total casualties: 0.39
# Correlation between 4_PERSONS and total casualties: 0.35
# Correlation between OCC_DOY and total casualties: 0.31
# Correlation between SEASON_NUM and total casualties: 0.23
# Correlation between OCC_DOW and total casualties: 0.22
# Correlation between 200000+ and total casualties: -0.17
# Correlation between OCC_MONTH and total casualties: 0.15
# Correlation between OCC_YEAR and total casualties: 0.15
# Correlation between BACHELOR_OR_ABOVE and total casualties: 0.14
# Correlation between 100000+ and total casualties: 0.14
# Correlation between OCC_DAY and total casualties: 0.14
# Correlation between OCC_HOUR and total casualties: -0.12
# Correlation between LAT and total casualties: 0.11
# Correlation between LONG and total casualties: -0.10
# Correlation between DIVISION and total casualties: -0.02

# %%
x1 = df_hood_grouped['5_OR_MORE_PERSONS']
x2 = df_hood_grouped['50000-100000']
x3 = df_hood_grouped['3_PERSONS']

# %%
results = ols("TOTAL_CASUALTIES ~  NO_EDU + TRADES_CERT + Unemployed + SECONDARY_OR_EQUIV + UNDER_50000  + x1 + POST_SECONDARY_DEGREE+ x2 + x3", data=df_hood_grouped).fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       TOTAL_CASUALTIES   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     40.42
# Date:                Sat, 15 Jul 2023   Prob (F-statistic):           2.10e-33
# Time:                        16:52:19   Log-Likelihood:                -568.00
# No. Observations:                 139   AIC:                             1156.
# Df Residuals:                     129   BIC:                             1185.
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -2.5476      2.920     -0.872      0.385      -8.325       3.230
# NO_EDU                    0.0116      0.002      6.391      0.000       0.008       0.015
# TRADES_CERT               0.0554      0.019      2.987      0.003       0.019       0.092
# Unemployed                0.0399      0.014      2.874      0.005       0.012       0.067
# SECONDARY_OR_EQUIV       -0.0038      0.003     -1.192      0.235      -0.010       0.003
# UNDER_50000              -0.0004      0.003     -0.151      0.880      -0.006       0.005
# x1                        0.0247      0.009      2.786      0.006       0.007       0.042
# POST_SECONDARY_DEGREE    -0.0125      0.004     -3.306      0.001      -0.020      -0.005
# x2                        0.0110      0.003      3.958      0.000       0.006       0.017
# x3                       -0.0308      0.006     -4.815      0.000      -0.043      -0.018
# ==============================================================================
# Omnibus:                       10.609   Durbin-Watson:                   1.590
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               15.270
# Skew:                           0.409   Prob(JB):                     0.000483
# Kurtosis:                       4.403   Cond. No.                     1.87e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x1 = df['5_OR_MORE_PERSONS']
x2 = df['50000-100000']
x3 = df['3_PERSONS']

# %%
df_hood_division = df.groupby([ 'HOOD_140', 'DIVISION' ]).size().reset_index(name='Count')

# %%
print(df_hood_division)
# Out:
#      HOOD_140  DIVISION  Count
# 0           1        23    129
# 1           1        31      2
# 2           1        43      1
# 3           2        13      1
# 4           2        22      1
# ..        ...       ...    ...
# 255       138        43     62
# 256       139        41      1
# 257       139        43     44
# 258       139        52      1
# 259       140        43      6
#
# [260 rows x 3 columns]

# %%
hood_total_count = df_hood_division.groupby('HOOD_140')['Count'].transform('sum')

df_hood_division['DIVISION_CONCENTRATION'] = (df_hood_division['Count'] / hood_total_count)*100

# %%
df_hood_division
# Out:
#      HOOD_140  DIVISION  Count  DIVISION_CONCENTRATION
# 0           1        23    129               97.727273
# 1           1        31      2                1.515152
# 2           1        43      1                0.757576
# 3           2        13      1                0.520833
# 4           2        22      1                0.520833
# ..        ...       ...    ...                     ...
# 255       138        43     62               75.609756
# 256       139        41      1                2.173913
# 257       139        43     44               95.652174
# 258       139        52      1                2.173913
# 259       140        43      6              100.000000
#
# [260 rows x 4 columns]

# %%
unique_hoods = df_hood_division['HOOD_140'].unique()
num_hoods = len(unique_hoods)
num_plots_per_row = 5
num_rows = (num_hoods - 1) // num_plots_per_row + 1

fig, axes = plt.subplots(num_rows, num_plots_per_row, figsize=(16, 3 * num_rows))
fig.tight_layout(h_pad=4)  # Increase the vertical spacing between subplots

for i, hood in enumerate(unique_hoods):
    row = i // num_plots_per_row
    col = i % num_plots_per_row
    ax = axes[row, col]
    hood_data = df_hood_division[df_hood_division['HOOD_140'] == hood]
    sns.barplot(data=hood_data, x='DIVISION', y='DIVISION_CONCENTRATION', ax=ax)
    ax.set_xlabel('DIVISION')
    ax.set_ylabel('DIVISION_CONCENTRATION')
    ax.set_title(f'HOOD_140: {hood}')
    ax.tick_params(axis='x', rotation=90)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group the data by HOOD_140 and DIVISION and calculate the count
grouped_data = df.groupby(['HOOD_140', 'DIVISION']).size().reset_index(name='Count')

# Pivot the data to have HOOD_140 as columns and DIVISION as index
pivot_data = grouped_data.pivot(index='DIVISION', columns='HOOD_140', values='Count').fillna(0)

# Plot the stacked bar graph
plt.figure(figsize=(10, 6))
pivot_data.plot(kind='bar', stacked=True)
plt.xlabel('DIVISION')
plt.ylabel('Count')
plt.title('Contribution of HOOD_140 to Count per DIVISION')
plt.legend(title='HOOD_140', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=90)
plt.show()
