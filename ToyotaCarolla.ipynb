# %%
import pandas as pd

# %%
df= pd.read_csv('/Users/mikeredshaw/Documents/Schulich MBAN/MMAI 5000 AI Fundamentals/ToyotaCorolla.csv')

# %%
df.info()
df.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1436 non-null   int64
#  1   Model              1436 non-null   object
#  2   Price              1436 non-null   int64
#  3   Age_08_04          1436 non-null   int64
#  4   Mfg_Month          1436 non-null   int64
#  5   Mfg_Year           1436 non-null   int64
#  6   KM                 1436 non-null   int64
#  7   Fuel_Type          1436 non-null   object
#  8   HP                 1436 non-null   int64
#  9   Met_Color          1436 non-null   int64
#  10  Color              1436 non-null   object
#  11  Automatic          1436 non-null   int64
#  12  CC                 1436 non-null   int64
#  13  Doors              1436 non-null   int64
#  14  Cylinders          1436 non-null   int64
#  15  Gears              1436 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Id                    int64
# Model                object
# Price                 int64
# Age_08_04             int64
# Mfg_Month             int64
# Mfg_Year              int64
# KM                    int64
# Fuel_Type            object
# HP                    int64
# Met_Color             int64
# Color                object
# Automatic             int64
# CC                    int64
# Doors                 int64
# Cylinders             int64
# Gears                 int64
# Quarterly_Tax         int64
# Weight                int64
# Mfr_Guarantee         int64
# BOVAG_Guarantee       int64
# Guarantee_Period      int64
# ABS                   int64
# Airbag_1              int64
# Airbag_2              int64
# Airco                 int64
# Automatic_airco       int64
# Boardcomputer         int64
# CD_Player             int64
# Central_Lock          int64
# Powered_Windows       int64
# Power_Steering        int64
# Radio                 int64
# Mistlamps             int64
# ...

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
fuel_mapping = {'Diesel': 1, 'Petrol': 2, 'CNG': 3}
df['Fuel_Type_Number'] = df['Fuel_Type'].map(fuel_mapping)

# %%
print(df['Fuel_Type'])
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434    Petrol
# 1435    Petrol
# Name: Fuel_Type, Length: 1436, dtype: object

# %%
df['Color'].unique()
# Out:
# array(['Blue', 'Silver', 'Black', 'White', 'Grey', 'Red', 'Green',
#        'Yellow', 'Violet', 'Beige'], dtype=object)

# %%
color_mapping = {'Blue' :1, 'Silver' :2, 'Black':3, 'White':4, 'Grey':5, 'Red':6, 'Green':7,
       'Yellow':8, 'Violet':9, 'Beige':10}
df['Color_Number'] = df['Color'].map(color_mapping)
df['Color_Number'].astype(int)
print(df.dtypes)
# Out:
# Id                    int64
# Model                object
# Price                 int64
# Age_08_04             int64
# Mfg_Month             int64
# Mfg_Year              int64
# KM                    int64
# Fuel_Type            object
# HP                    int64
# Met_Color             int64
# Color                object
# Automatic             int64
# CC                    int64
# Doors                 int64
# Cylinders             int64
# Gears                 int64
# Quarterly_Tax         int64
# Weight                int64
# Mfr_Guarantee         int64
# BOVAG_Guarantee       int64
# Guarantee_Period      int64
# ABS                   int64
# Airbag_1              int64
# Airbag_2              int64
# Airco                 int64
# Automatic_airco       int64
# Boardcomputer         int64
# CD_Player             int64
# Central_Lock          int64
# Powered_Windows       int64
# Power_Steering        int64
# Radio                 int64
# Mistlamps             int64
# ...

# %%
df
# Out:
#         Id                                              Model  Price
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500  \
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...
# ...

# %%
df.head()
# Out:
#    Id                                          Model  Price  Age_08_04
# 0   1  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23  \
# 1   2  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5    TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Radio  Mistlamps
# 0         10      2002  46986    Diesel  90          1  ...     0          0  \
# 1         10      2002  72937    Diesel  90          1  ...     0          0
# 2          9      2002  41711    Diesel  90          1  ...     0          0
# 3          7      2002  48000    Diesel  90          0  ...     0          0
# 4          3      2002  38500    Diesel  90          0  ...     0          1
#
#    Sport_Model  Backseat_Divider  Metallic_Rim  Radio_cassette
# ...

# %%
df_training_size = int(df['Id'].count()*0.5)
df_training = df.iloc[0:(df_training_size-1)]
print(df_training)
# Out:
#       Id                                              Model  Price  Age_08_04
# 0      1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23  \
# 1      2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2      3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3      4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4      5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# ..   ...                                                ...    ...        ...
# 712  716  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8750         65
# 713  717  TOYOTA Corolla 1.6 16V LIFTB LINEA LUNA 4/5-Doors   9500         58
# 714  718  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...   8450         68
# 715  719  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...   8490         62
# 716  720     TOYOTA Corolla 1.6 Linea Terra Sedan 4/5-Doors   8750         60
#
# ...

# %%
df_validation_size = int(df['Id'].count()*0.3)
df_validation = df.iloc[df_training_size : ((df_training_size + df_validation_size)-1)]
print(df_validation)
# Out:
#         Id                                              Model  Price
# 718    722   TOYOTA Corolla 1.6 Linea Luna Wagon Stationwagen   9950  \
# 719    723  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...   8500
# 720    724  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...   8450
# 721    725  TOYOTA Corolla 1.6 16V SEDAN LINEA LUNA 4/5-Doors   7900
# 722    726  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...   8750
# ...    ...                                                ...    ...
# 1142  1148     TOYOTA Corolla 1.3 Linea Terra 3 drs 2/3-Doors   7950
# 1143  1149  TOYOTA Corolla 1.6 16V LIFTB LINEA LUNA AUT4 4...   8950
# 1144  1150  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7750
# 1145  1151  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...   6450
# 1146  1152  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...   6900
#
#       Age_08_04  Mfg_Month  Mfg_Year      KM Fuel_Type   HP  Met_Color  ...
# ...

# %%
df_test_size = int(df['Id'].count()*0.2)
df_test = df.iloc[(df_training_size + df_validation_size) : -1]
print(df_test)
# Out:
#         Id                                              Model  Price
# 1148  1154        TOYOTA Corolla 1.3 HB LINEA TERRA 2/3-Doors   6750  \
# 1149  1155  TOYOTA Corolla 1.3 16V SEDAN LINEA TERRA AUT3 ...   8050
# 1150  1156  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...   9500
# 1151  1157  TOYOTA Corolla 1.6 16V SEDAN LINEA TERRA 4/5-D...   7750
# 1152  1158  TOYOTA Corolla 1.6 16V WAGON LINEA TERRA Stati...   8500
# ...    ...                                                ...    ...
# 1430  1437  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8450
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
#
#       Age_08_04  Mfg_Month  Mfg_Year      KM Fuel_Type   HP  Met_Color  ...
# ...

# %%
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# Define the predictor variables
predictors = ['Age_08_04', 'KM', 'Fuel_Type_Number', 'HP', 'Automatic', 'Doors', 'Quarterly_Tax',
              'Mfr_Guarantee', 'Guarantee_Period', 'Airco', 'Automatic_airco',
              'CD_Player', 'Powered_Windows', 'Sport_Model', 'Tow_Bar']

# Create the feature matrices and target variables for training, test, and validation
X_train = df_training[predictors]
y_train = df_training['Price']

X_test = df_test[predictors]
y_test = df_test['Price']

X_validation = df_validation[predictors]
y_validation = df_validation['Price']

# Create an instance of the LinearRegression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Print the coefficients and intercept
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 11068.607871390195
# Coefficients: [-1.15247853e+02 -2.29845823e-02 -7.67195185e+02  5.39729511e+01
#   3.49142185e+02  1.82678940e+02  1.66300254e+01  2.59471925e+02
#   7.31457191e+01  2.70248718e+02  2.31686331e+03  2.13542686e+02
#   5.77015584e+02  8.71202945e+02 -4.27620933e+01]
