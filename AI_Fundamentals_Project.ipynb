# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mredshaw/AI-Fundamentals-Project/main/Group%20Project%20Data-SFD%20Data-Toronto%20Police.csv')

# %%
pip install python-certifi-win32
# Out:
# Requirement already satisfied: python-certifi-win32 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: wrapt>=1.10.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-certifi-win32) (1.15.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-certifi-win32) (2023.5.7)
# Requirement already satisfied: setuptools-scm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-certifi-win32) (7.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mikeredshaw/Library/Python/3.11/lib/python/site-packages (from setuptools-scm->python-certifi-win32) (23.1)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from setuptools-scm->python-certifi-win32) (65.5.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from setuptools-scm->python-certifi-win32) (4.5.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mredshaw/AI-Fundamentals-Project/main/Group%20Project%20Data-SFD%20Data-Toronto%20Police.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mredshaw/AI-Fundamentals-Project/main/Group%20Project%20Data-SFD%20Data-Toronto%20Police.csv')

# %%
df
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5702 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5703 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5704 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5705 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5706 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
#       OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 0         2004        May   Saturday      136       15  ...           Night  \
# 1         2004       July     Monday      208       26  ...         Evening
# 2         2004        May     Friday      135       14  ...       Afternoon
# 3         2004   December     Sunday      354       19  ...           Night
# 4         2004      April     Monday      103       12  ...         Evening
# ...        ...        ...        ...      ...      ...  ...             ...
# 5702      2022       June   Thursday      153        2  ...           Night
# 5703      2022       July     Sunday      198       17  ...           Night
# 5704      2022   February     Monday       52       21  ...           Night
# 5705      2022  September     Sunday      254       11  ...           Night
# 5706      2022      April  Wednesday      117       27  ...       Afternoon
#
#      DIVISION DEATH  INJURIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0         D41     0         0       142            Woburn North      137  \
# 1         D23     0         0         1  West Humber-Clairville        1
# 2         D31     1         1        24             Black Creek       24
# 3         D51     1         0       168     Downtown Yonge East       75
# 4         D42     0         0       146            Malvern East      132
# ...       ...   ...       ...       ...                     ...      ...
# 5702      D33     0         1        53              Henry Farm       53
# 5703      D14     1         1       164        Wellington Place       77
# 5704      D43     0         0       135             Morningside      135
# 5705      D11     0         2        83          Dufferin Grove       83
# 5706      D51     0         0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                               Woburn (137) -79.234955  43.781528
# 1                 West Humber-Clairville (1) -79.618218  43.733547
# 2                           Black Creek (24) -79.518759  43.769157
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665
# 4                              Malvern (132) -79.212435  43.812075
# ...                                      ...        ...        ...
# 5702                         Henry Farm (53) -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920
# 5704                       Morningside (135) -79.196217  43.786621
# 5705                     Dufferin Grove (83) -79.443993  43.658083
# 5706                          Moss Park (73) -79.369456  43.654519
#
# [5707 rows x 21 columns]

# %%
df.set_index('EVENT_UNIQUE_ID', inplace=True)

# %%
df
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5702 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5703 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5704 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5705 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5706 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
#       OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 0         2004        May   Saturday      136       15  ...           Night  \
# 1         2004       July     Monday      208       26  ...         Evening
# 2         2004        May     Friday      135       14  ...       Afternoon
# 3         2004   December     Sunday      354       19  ...           Night
# 4         2004      April     Monday      103       12  ...         Evening
# ...        ...        ...        ...      ...      ...  ...             ...
# 5702      2022       June   Thursday      153        2  ...           Night
# 5703      2022       July     Sunday      198       17  ...           Night
# 5704      2022   February     Monday       52       21  ...           Night
# 5705      2022  September     Sunday      254       11  ...           Night
# 5706      2022      April  Wednesday      117       27  ...       Afternoon
#
#      DIVISION DEATH  INJURIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0         D41     0         0       142            Woburn North      137  \
# 1         D23     0         0         1  West Humber-Clairville        1
# 2         D31     1         1        24             Black Creek       24
# 3         D51     1         0       168     Downtown Yonge East       75
# 4         D42     0         0       146            Malvern East      132
# ...       ...   ...       ...       ...                     ...      ...
# 5702      D33     0         1        53              Henry Farm       53
# 5703      D14     1         1       164        Wellington Place       77
# 5704      D43     0         0       135             Morningside      135
# 5705      D11     0         2        83          Dufferin Grove       83
# 5706      D51     0         0        73               Moss Park       73
#
#                            NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                               Woburn (137) -79.234955  43.781528
# 1                 West Humber-Clairville (1) -79.618218  43.733547
# 2                           Black Creek (24) -79.518759  43.769157
# 3                 Church-Yonge Corridor (75) -79.378870  43.660665
# 4                              Malvern (132) -79.212435  43.812075
# ...                                      ...        ...        ...
# 5702                         Henry Farm (53) -79.362941  43.771764
# 5703  Waterfront Communities-The Island (77) -79.402702  43.643920
# 5704                       Morningside (135) -79.196217  43.786621
# 5705                     Dufferin Grove (83) -79.443993  43.658083
# 5706                          Moss Park (73) -79.369456  43.654519
#
# [5707 rows x 21 columns]

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#                          X          Y  OBJECTID                OCC_DATE
# EVENT_UNIQUE_ID
# GO-20041036512  -79.235253  43.739524        95  2004/10/15 04:00:00+00  \
# GO-20041053840  -79.494743  43.673984       158  2004/06/03 04:00:00+00
# GO-2004120070   -85.488744   0.000000        79  2004/01/03 05:00:00+00
# GO-2004125755   -79.233887  43.781741        32  2004/01/08 05:00:00+00
# GO-2004126451   -79.256025  43.732873        87  2004/01/05 05:00:00+00
# ...                    ...        ...       ...                     ...
# GO-2022976987   -79.545348  43.721709      5630  2022/05/24 04:00:00+00
# GO-2022978548   -79.197577  43.758964      5354  2022/05/24 04:00:00+00
# GO-202298250    -79.458334  43.670092      5345  2022/01/16 05:00:00+00
# GO-2022985243   -79.557109  43.669408      5608  2022/05/25 04:00:00+00
# GO-20229964     -79.535360  43.710318      5397  2022/01/02 05:00:00+00
#
#                  OCC_YEAR OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR
# EVENT_UNIQUE_ID
# GO-20041036512       2004   October     Friday      289       15         5  \
# GO-20041053840       2004      June   Thursday      155        3        20
# GO-2004120070        2004   January   Saturday        3        3         1
# GO-2004125755        2004   January   Thursday        8        8         8
# GO-2004126451        2004   January     Monday        5        5        13
# ...                   ...       ...        ...      ...      ...       ...
# GO-2022976987        2022       May    Tuesday      144       24        17
# GO-2022978548        2022       May    Tuesday      144       24        21
# GO-202298250         2022   January     Sunday       16       16         2
# GO-2022985243        2022       May  Wednesday      145       25        18
# GO-20229964          2022   January     Sunday        2        2        17
#
#                 OCC_TIME_RANGE DIVISION  DEATH  INJURIES HOOD_158
# EVENT_UNIQUE_ID
# GO-20041036512           Night      D43      0         0      138  \
# GO-20041053840         Evening      D12      0         0      111
# GO-2004120070            Night      D54      0         0      NSA
# GO-2004125755          Morning      D42      1         0      142
# GO-2004126451        Afternoon      D41      0         1      124
# ...                        ...      ...    ...       ...      ...
# GO-2022976987        Afternoon      D23      0         0        5
# GO-2022978548          Evening      D43      0         1      136
# GO-202298250             Night      D11      0         0       91
# GO-2022985243          Evening      D22      0         0       10
# GO-20229964          Afternoon      D12      1         0       23
#
#                     NEIGHBOURHOOD_158 HOOD_140          NEIGHBOURHOOD_140
# EVENT_UNIQUE_ID
# GO-20041036512          Eglinton East      138        Eglinton East (138)  \
# GO-20041053840      Rockcliffe-Smythe      111    Rockcliffe-Smythe (111)
# GO-2004120070                     NSA      NSA                        NSA
# GO-2004125755            Woburn North      137               Woburn (137)
# GO-2004126451            Kennedy Park      124         Kennedy Park (124)
# ...                               ...      ...                        ...
# GO-2022976987        Elms-Old Rexdale        5       Elms-Old Rexdale (5)
# GO-2022978548               West Hill      136            West Hill (136)
# GO-202298250       Weston-Pelham Park       91    Weston-Pellam Park (91)
# GO-2022985243      Princess-Rosethorn       10    Princess-Rosethorn (10)
# GO-20229964      Pelmo Park-Humberlea       23  Pelmo Park-Humberlea (23)
#
#                  LONG_WGS84  LAT_WGS84
# EVENT_UNIQUE_ID
# GO-20041036512   -79.235253  43.739524
# GO-20041053840   -79.494743  43.673984
# GO-2004120070    -85.488744   0.000000
# GO-2004125755    -79.233887  43.781741
# GO-2004126451    -79.256025  43.732873
# ...                     ...        ...
# GO-2022976987    -79.545348  43.721709
# GO-2022978548    -79.197577  43.758964
# GO-202298250     -79.458334  43.670092
# GO-2022985243    -79.557109  43.669408
# GO-20229964      -79.535360  43.710318
#
# [5707 rows x 20 columns]

# %%
df.set_index('OBJECTID', inplace=True)

# %%
df
# Out:
#                   X          Y                OCC_DATE  OCC_YEAR  OCC_MONTH
# OBJECTID
# 1        -79.234955  43.781528  2004/05/15 04:00:00+00      2004        May  \
# 2        -79.618218  43.733547  2004/07/26 04:00:00+00      2004       July
# 3        -79.518759  43.769157  2004/05/14 04:00:00+00      2004        May
# 4        -79.378870  43.660665  2004/12/19 05:00:00+00      2004   December
# 5        -79.212435  43.812075  2004/04/12 04:00:00+00      2004      April
# ...             ...        ...                     ...       ...        ...
# 5703     -79.362941  43.771764  2022/06/02 04:00:00+00      2022       June
# 5704     -79.402702  43.643920  2022/07/17 04:00:00+00      2022       July
# 5705     -79.196217  43.786621  2022/02/21 05:00:00+00      2022   February
# 5706     -79.443993  43.658083  2022/09/11 04:00:00+00      2022  September
# 5707     -79.369456  43.654519  2022/04/27 04:00:00+00      2022      April
#
#             OCC_DOW  OCC_DOY  OCC_DAY  OCC_HOUR OCC_TIME_RANGE DIVISION
# OBJECTID
# 1          Saturday      136       15         1          Night      D41  \
# 2            Monday      208       26        23        Evening      D23
# 3            Friday      135       14        16      Afternoon      D31
# 4            Sunday      354       19         0          Night      D51
# 5            Monday      103       12        22        Evening      D42
# ...             ...      ...      ...       ...            ...      ...
# 5703       Thursday      153        2         3          Night      D33
# 5704         Sunday      198       17         3          Night      D14
# 5705         Monday       52       21         5          Night      D43
# 5706         Sunday      254       11         1          Night      D11
# 5707      Wednesday      117       27        17      Afternoon      D51
#
#           DEATH  INJURIES HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# OBJECTID
# 1             0         0      142            Woburn North      137  \
# 2             0         0        1  West Humber-Clairville        1
# 3             1         1       24             Black Creek       24
# 4             1         0      168     Downtown Yonge East       75
# 5             0         0      146            Malvern East      132
# ...         ...       ...      ...                     ...      ...
# 5703          0         1       53              Henry Farm       53
# 5704          1         1      164        Wellington Place       77
# 5705          0         0      135             Morningside      135
# 5706          0         2       83          Dufferin Grove       83
# 5707          0         0       73               Moss Park       73
#
#                                NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# OBJECTID
# 1                                   Woburn (137)  -79.234955  43.781528
# 2                     West Humber-Clairville (1)  -79.618218  43.733547
# 3                               Black Creek (24)  -79.518759  43.769157
# 4                     Church-Yonge Corridor (75)  -79.378870  43.660665
# 5                                  Malvern (132)  -79.212435  43.812075
# ...                                          ...         ...        ...
# 5703                             Henry Farm (53)  -79.362941  43.771764
# 5704      Waterfront Communities-The Island (77)  -79.402702  43.643920
# 5705                           Morningside (135)  -79.196217  43.786621
# 5706                         Dufferin Grove (83)  -79.443993  43.658083
# 5707                              Moss Park (73)  -79.369456  43.654519
#
# [5707 rows x 19 columns]

# %%
df_division = df[['DIVISION', 'DEATH', 'INJURIES', 'OCC_YEAR']]

# %%
df_division
# Out:
#          DIVISION  DEATH  INJURIES  OCC_YEAR
# OBJECTID
# 1             D41      0         0      2004
# 2             D23      0         0      2004
# 3             D31      1         1      2004
# 4             D51      1         0      2004
# 5             D42      0         0      2004
# ...           ...    ...       ...       ...
# 5703          D33      0         1      2022
# 5704          D14      1         1      2022
# 5705          D43      0         0      2022
# 5706          D11      0         2      2022
# 5707          D51      0         0      2022
#
# [5707 rows x 4 columns]

# %%
df_division.sort_values('DIVISION', ascending=True)
# Out:
#          DIVISION  DEATH  INJURIES  OCC_YEAR
# OBJECTID
# 4138          D11      0         0      2019
# 1116          D11      0         1      2009
# 3641          D11      0         1      2018
# 4474          D11      1         0      2020
# 2808          D11      0         1      2016
# ...           ...    ...       ...       ...
# 4376          D55      0         0      2019
# 1802          D55      0         1      2011
# 951           D55      0         1      2008
# 3173          D55      0         0      2017
# 4293          D55      0         1      2019
#
# [5707 rows x 4 columns]

# %%
df_division_grouped = df_division.groupby(["DIVISION","OCC_YEAR"]).agg("sum")

# %%
df_division_grouped
# Out:
#                    DEATH  INJURIES
# DIVISION OCC_YEAR
# D11      2004          0         0
#          2005          2         1
#          2006          0         3
#          2007          1         0
#          2008          0         0
# ...                  ...       ...
# D55      2018          0         2
#          2019          0         6
#          2020          0         3
#          2021          1         3
#          2022          2         4
#
# [323 rows x 2 columns]

# %%
df_division_grouped['TOTAL_INCIDENTS'] = df_division_grouped['DEATH'] + df_division_grouped['INJURIES']

# %%
df_division_grouped
# Out:
#                    DEATH  INJURIES  TOTAL_INCIDENTS
# DIVISION OCC_YEAR
# D11      2004          0         0                0
#          2005          2         1                3
#          2006          0         3                3
#          2007          1         0                1
#          2008          0         0                0
# ...                  ...       ...              ...
# D55      2018          0         2                2
#          2019          0         6                6
#          2020          0         3                3
#          2021          1         3                4
#          2022          2         4                6
#
# [323 rows x 3 columns]

# %%
df_division_yr = df_division.groupby(["OCC_YEAR"])

# %%
df_division_yr

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df_division_grouped['TOTAL_INCIDENTS'] = df_division_grouped['TOTAL_INCIDENTS'].apply(pd.Series)

# %%
sns.lineplot(data=df_division_grouped, x='OCC_YEAR', y='TOTAL_INCIDENTS', hue='DIVISION')
plt.show()

# %%
plt.show()

# %%
df_division_grouped
# Out:
#                    DEATH  INJURIES  TOTAL_INCIDENTS
# DIVISION OCC_YEAR
# D11      2004          0         0                0
#          2005          2         1                3
#          2006          0         3                3
#          2007          1         0                1
#          2008          0         0                0
# ...                  ...       ...              ...
# D55      2018          0         2                2
#          2019          0         6                6
#          2020          0         3                3
#          2021          1         3                4
#          2022          2         4                6
#
# [323 rows x 3 columns]

# %%
df_division_grouped_new = df_division_grouped.reset_index()

sns.lmplot(data=df_division_grouped_new, x='OCC_YEAR', y='TOTAL_INCIDENTS', hue='DIVISION', truncate=False)
plt.show()

# %%
df_division_grouped_new
# Out:
#     DIVISION  OCC_YEAR  DEATH  INJURIES  TOTAL_INCIDENTS
# 0        D11      2004      0         0                0
# 1        D11      2005      2         1                3
# 2        D11      2006      0         3                3
# 3        D11      2007      1         0                1
# 4        D11      2008      0         0                0
# ..       ...       ...    ...       ...              ...
# 318      D55      2018      0         2                2
# 319      D55      2019      0         6                6
# 320      D55      2020      0         3                3
# 321      D55      2021      1         3                4
# 322      D55      2022      2         4                6
#
# [323 rows x 5 columns]

# %%
division_name = 'D31'
division_data = df_division_grouped_new[df_division_grouped_new['DIVISION'] == division_name]

sns.lmplot(data=division_data, x='OCC_YEAR', y='TOTAL_INCIDENTS', truncate=False)
plt.title(f"Line of Best Fit - {division_name}")
plt.show()

# %%
for division_name in df_division_grouped_new['DIVISION'].unique():
    division_data = df_division_grouped_new[df_division_grouped_new['DIVISION'] == division_name]

    sns.lmplot(data=division_data, x='OCC_YEAR', y='TOTAL_INCIDENTS', truncate=False)
    plt.title(f"Line of Best Fit - {division_name}")
    plt.show()

# %%
df_yearly_total = df_division_grouped_new.groupby('OCC_YEAR')['TOTAL_INCIDENTS'].sum().reset_index()

sns.lmplot(data=df_yearly_total, x='OCC_YEAR', y='TOTAL_INCIDENTS')
plt.title('Total Incidents by Year')
plt.xlabel('Year')
plt.ylabel('Total Incidents')
plt.show()

# %%
df_yearly_total = df_division_grouped_new.groupby('OCC_YEAR')['TOTAL_INCIDENTS'].sum().reset_index()

# Iterate over each division
for division_name in df_division_grouped_new['DIVISION'].unique():
    division_data = df_division_grouped_new[df_division_grouped_new['DIVISION'] == division_name]

    # Plot the lmplot for each division
    sns.lmplot(data=division_data, x='OCC_YEAR', y='TOTAL_INCIDENTS', truncate=False)
    plt.title(f"Line of Best Fit - {division_name}")
    plt.show()

# Plot the lmplot for the average of all divisions
sns.lmplot(data=df_yearly_total, x='OCC_YEAR', y='TOTAL_INCIDENTS', truncate=False)
plt.title('Average of All Divisions')
plt.show()

# %%
df_yearly_avg = df_division_grouped_new.groupby(['OCC_YEAR', 'DIVISION'])['TOTAL_INCIDENTS'].mean().reset_index()

# Iterate over each division
for division_name in df_division_grouped_new['DIVISION'].unique():
    division_data = df_yearly_avg[df_yearly_avg['DIVISION'] == division_name]

    # Plot the lmplot for each division
    lmplot = sns.lmplot(data=division_data, x='OCC_YEAR', y='TOTAL_INCIDENTS', truncate=False)
    plt.title(f"Line of Best Fit - {division_name}")

    # Add the average line to the lmplot
    avg_line = df_yearly_avg.groupby('OCC_YEAR')['TOTAL_INCIDENTS'].mean().reset_index()
    plt.plot(avg_line['OCC_YEAR'], avg_line['TOTAL_INCIDENTS'], color='red', linestyle='--', label='Average')
    
    # Show legend
    plt.legend()
    
    plt.show()
